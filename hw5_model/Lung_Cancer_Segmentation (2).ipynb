# %% [markdown]
# <a href="https://colab.research.google.com/github/quockhanhdao/Lung_Tumours_Segmentation/blob/main/Lung_Cancer_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install

# %%
# !pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Using cached einops-0.6.0-py3-none-any.whl (41 kB)
# Installing collected packages: einops
# Successfully installed einops-0.6.0

# %%
# !pip install -q "monai-weekly[tqdm, nibabel, gdown, ignite, einops]"

# %%
# !python -c "import matplotlib" || pip install -q matplotlib
# %matplotlib inline
# !pip install einops0
# !python -c "import monai" || pip install 'monai[all]'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement einops0 (from versions: none)
# ERROR: No matching distribution found for einops0
# 2023-04-15 04:47:21.772014: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-15 04:47:26.813616: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# # Import libraries

# %%
import os
import warnings
warnings.filterwarnings("ignore")

import monai
from monai.networks.nets import UNETR

from monai.apps import DecathlonDataset
from monai.data import DataLoader, CacheDataset, decollate_batch
from monai.utils import first, set_determinism
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.transforms import (
    LoadImage, 
    LoadImageD, 
    EnsureChannelFirstD, 
    AddChannelD, 
    ScaleIntensityD, 
    ToTensorD, 
    Compose, 
    AsDiscreteD, 
    SpacingD, 
    OrientationD, 
    ResizeD, 
    RandAffineD,
    AsDiscrete,
    AsDiscreted,
    EnsureTyped,
    EnsureType,
)

import torch
import numpy as np
import matplotlib.pyplot as plt

print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# 1
# Tesla T4

# %%
cuda = torch.cuda.is_available()

device = torch.device("cuda" if cuda else "cpu")
num_workers = 4 if cuda else 0

print('You are using gpu if true, cpu if false:', cuda)
# Out:
# You are using gpu if true, cpu if false: True

# %% [markdown]
# # Load data

# %% [markdown]
# ## Test data

# %%
# Dowload data, src: http://medicaldecathlon.com/
dataset = DecathlonDataset(root_dir = "./", 
                           task = "Task06_Lung", section = "training", 
                           transform = None, download = True)
print(f"\nnumber of subjects: {len(dataset)}.\nThe first element in the dataset is {dataset[0]}.")
# Out:
# Task06_Lung.tar: 8.53GB [08:39, 17.7MB/s]
# 2023-04-15 04:56:21,561 - INFO - Downloaded: Task06_Lung.tar
# 2023-04-15 04:57:00,460 - INFO - Verified 'Task06_Lung.tar', md5: 8afd997733c7fc0432f71255ba4e52dc.
# 2023-04-15 04:57:00,464 - INFO - Writing into directory: ..
# Loading dataset: 100%|██████████| 51/51 [00:00<00:00, 225167.90it/s]
# number of subjects: 51.
# The first element in the dataset is {'image': 'Task06_Lung/imagesTr/lung_014.nii.gz', 'label': 'Task06_Lung/labelsTr/lung_014.nii.gz'}.

# %%
# Load random to check
loader = LoadImageD(keys=("image", "label"))
data_check = loader({"image": "Task06_Lung/imagesTr/lung_014.nii.gz", 
                     "label": "Task06_Lung/labelsTr/lung_014.nii.gz"})
print(f"image shape: {data_check['image'].shape} \nlabel shape: {data_check['label'].shape}")
# Out:
# image shape: torch.Size([512, 512, 589])
# label shape: torch.Size([512, 512, 589])

# %%
# Visualize check image and label
slide = 379
plt.figure("check", (12, 6))

plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(data_check['image'][:, :, slide], cmap = "gray")

plt.subplot(1, 2, 2)
plt.title("label")
plt.imshow(data_check['image'][:, :, slide], cmap = "gray")
plt.imshow(data_check['label'][:, :, slide], cmap = 'jet', alpha = 0.5)

plt.show()

# %% [markdown]
# ## Load training set

# %%
# Set up transform
KEYS = ["image", "label"]
transform = Compose([
    LoadImageD(keys = KEYS),
    EnsureChannelFirstD(keys = KEYS),
    OrientationD(KEYS, axcodes='RAS'),
    SpacingD(keys = KEYS, 
             pixdim = (1., 1., 1.), 
             mode = ('bilinear', 'nearest')),
    ScaleIntensityD(keys = "image"),
    ResizeD(KEYS, 
            (128, 128, 64), 
            mode=('trilinear', 'nearest')),
    RandAffineD(keys = KEYS, 
                spatial_size = (128, 128, 64),
                rotate_range = (0, 0, np.pi/12),
                scale_range = (0.1, 0.1, 0.1),
                mode = ('bilinear', 'nearest'),
                prob = 1.0),
    ToTensorD(KEYS),
])

# %%
from monai.transforms.intensity.dictionary import ScaleIntensityRanged
# Change Transforms here
KEYS = ["image", "label"]
transform = Compose([
    LoadImageD(keys=KEYS),
    EnsureChannelFirstD(keys=KEYS),
    OrientationD(KEYS, axcodes='RAS'),
    SpacingD(keys=KEYS, pixdim=(1., 1., 1.), mode=('bilinear', 'nearest')),
    ScaleIntensityRanged(keys="image", a_min=-1000, a_max=500, b_min=0.0, b_max=1.0, clip=True),
    ResizeD(KEYS, (128, 128, 64), mode=('trilinear', 'nearest')),
    RandAffineD(keys=KEYS,
                spatial_size=(128, 128, 64),
                prob=0.5,
                rotate_range=(np.pi/12, np.pi/12, np.pi/12),
                shear_range=(0.1, 0.1, 0.1),
                translate_range=(10, 10, 10),
                scale_range=(0.1, 0.1, 0.1),
                mode=('bilinear', 'nearest')),
    ToTensorD(KEYS),
])

# %%
# Load data
dataset = DecathlonDataset(root_dir = "./",
                           task = "Task06_Lung", section = "training",
                           transform = transform, download = True)

train_loader = DataLoader(dataset, batch_size = 1, shuffle = True, num_workers = 4)
# Out:
# 2023-04-15 05:09:22,658 - INFO - Verified 'Task06_Lung.tar', md5: 8afd997733c7fc0432f71255ba4e52dc.
# 2023-04-15 05:09:22,660 - INFO - File exists: Task06_Lung.tar, skipped downloading.
# 2023-04-15 05:09:22,664 - INFO - Non-empty folder exists in Task06_Lung, skipped extracting.
# Loading dataset: 100%|██████████| 51/51 [12:39<00:00, 14.90s/it]

# %%
# Check transformed data
print(f"Length of training set: {len(train_loader)}")

check_training = first(train_loader)
training_image, training_label = check_training['image'], check_training['label']
print(f"check data training image shape: {training_image.shape} \ncheck data training label shape: {training_label.shape}")

# Trying to understand what the dimension 2 of the data is
print(training_image[0, :, 0, 0, 39])
# Out:
# Length of training set: 51
# check data training image shape: torch.Size([1, 1, 128, 128, 64])
# check data training label shape: torch.Size([1, 1, 128, 128, 64])
# metatensor([0.])

# %%
slide = 50
plt.figure("Training Data", (12, 12))

plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(training_image[0, 0, :, :, slide], cmap = "gray")

plt.subplot(1, 2, 2)
plt.title("label")
plt.imshow(training_image[0, 0, :, :, slide], cmap = "gray")
plt.imshow(training_label[0, 0, :, :, slide], cmap = 'jet', alpha = 0.4)

plt.show()

# %% [markdown]
# ## Load validation set

# %%
# Set up transform
val_transform = Compose([
    LoadImageD(keys = KEYS),
    EnsureChannelFirstD(keys = KEYS),
    OrientationD(KEYS, axcodes='RAS'),
    SpacingD(keys = KEYS, pixdim = (1., 1., 1.), mode = ('bilinear', 'nearest')),
    ScaleIntensityD(keys = "image"),
    ResizeD(KEYS, (128, 128, 64), mode=('trilinear', 'nearest')),
    ToTensorD(KEYS),
])

# Load data
val_dataset = DecathlonDataset(root_dir = "./",
                           task = "Task06_Lung", section = "validation",
                           transform = val_transform, download = True)

val_loader = DataLoader(val_dataset, batch_size = 1, shuffle = True, num_workers = 4)
# Out:
# 2023-04-15 05:29:22,154 - INFO - Verified 'Task06_Lung.tar', md5: 8afd997733c7fc0432f71255ba4e52dc.
# 2023-04-15 05:29:22,156 - INFO - File exists: Task06_Lung.tar, skipped downloading.
# 2023-04-15 05:29:22,158 - INFO - Non-empty folder exists in Task06_Lung, skipped extracting.
# Loading dataset: 100%|██████████| 12/12 [03:16<00:00, 16.35s/it]

# %%
#change transform here
val_transform = Compose([
    LoadImageD(keys=KEYS),
    EnsureChannelFirstD(keys=KEYS),
    OrientationD(KEYS, axcodes='RAS'),
    SpacingD(keys=KEYS, pixdim=(1., 1., 1.), mode=('bilinear', 'nearest')),
    ScaleIntensityD(keys="image"),
    CropForegroundD(keys=KEYS, source_key="image"),
    CenterSpatialCropD(KEYS, roi_size=(128, 128, 64)),
    ToTensorD(KEYS),
])

# %%
# Check transformed data
print(f"Length of validation set: {len(val_loader)}")

check_val = first(val_loader)
val_image, val_label = check_val['image'], check_val['label']
print(f"check data image shape: {val_image.shape} \ncheck data label shape: {val_label.shape}")
# Out:
# Length of validation set: 12
# check data image shape: torch.Size([1, 1, 128, 128, 64])
# check data label shape: torch.Size([1, 1, 128, 128, 64])

# %%
slide = 29
plt.figure("Validation Data", (12, 12))

plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(val_image[0, 0, :, :, slide], cmap = "gray")

plt.subplot(1, 2, 2)
plt.title("label")
plt.imshow(val_image[0, 0, :, :, slide], cmap = "gray")
plt.imshow(val_label[0, 0, :, :, slide], cmap = 'jet', alpha = 0.5)

plt.show()

# %% [markdown]
# # Model, Loss, Optimizer

# %%
device = torch.device("cuda:0")

UNet_metadata = dict(
    spatial_dims = 3,
    in_channels = 1,
    out_channels = 2,
    channels = (64, 128, 256, 512),
    strides = (2, 2, 2),
    num_res_units = 2,
    norm = Norm.BATCH,
)

model = UNet(**UNet_metadata).to(device) # using UNet model

loss_function = DiceLoss(include_background = False, to_onehot_y = True, softmax = True) # using Dice Loss function
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001) # using Adam optimizer
dice_metric = DiceMetric(include_background = False, reduction = "mean")

# %%
#change unet here
from monai.networks.nets import UNETR
model = UNETR(
    in_channels=1,
    out_channels=14,
    img_size=(128, 128, 64),
    feature_size=16,
    hidden_size=768,
    mlp_dim=3072,
    num_heads=12,
    pos_embed="perceptron",
    norm_name="instance",
    res_block=True,
    dropout_rate=0.0,
).to(device)




loss_function = DiceLoss(include_background = False, to_onehot_y = True, softmax = True) # using Dice Loss function
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-5)
dice_metric = DiceMetric(include_background = False, reduction = "mean")
# Out:
# ---------------------------------------------------------------------------
# OptionalImportError                       Traceback (most recent call last)
# <ipython-input-45-1eca1681b683> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-43-1eca1681b683> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-42-1eca1681b683> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-41-1eca1681b683> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-40-1eca1681b683> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-39-75bffab37e83> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-37-75bffab37e83> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-35-75bffab37e83> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-34-75bffab37e83> in <cell line: 3>()
#       1 #change unet here
#       2 from monai.networks.nets import UNETR
# ----> 3 model = UNETR(
#       4     in_channels=1,
#       5     out_channels=14,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
#     [... skipping hidden 1 frame]
#
# <ipython-input-33-b9a63c8be98f> in <cell line: 2>()
#       1 #change unet here
# ----> 2 model = UNETR(
#       3     in_channels=1,
#       4     out_channels=14,
#       5     img_size=(96, 96, 96),
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/unetr.py in __init__(self, in_channels, out_channels, img_size, feature_size, hidden_size, mlp_dim, num_heads, pos_embed, norm_name, conv_block, res_block, dropout_rate, spatial_dims, qkv_bias)
#      89         self.hidden_size = hidden_size
#      90         self.classification = False
# ---> 91         self.vit = ViT(
#      92             in_channels=in_channels,
#      93             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/nets/vit.py in __init__(self, in_channels, img_size, patch_size, hidden_size, mlp_dim, num_layers, num_heads, pos_embed, classification, num_classes, dropout_rate, spatial_dims, post_activation, qkv_bias)
#      88
#      89         self.classification = classification
# ---> 90         self.patch_embedding = PatchEmbeddingBlock(
#      91             in_channels=in_channels,
#      92             img_size=img_size,
#
# /usr/local/lib/python3.9/dist-packages/monai/networks/blocks/patchembedding.py in __init__(self, in_channels, img_size, patch_size, hidden_size, num_heads, pos_embed, dropout_rate, spatial_dims)
#      97             axes_len = {f"p{i+1}": p for i, p in enumerate(patch_size)}
#      98             self.patch_embeddings = nn.Sequential(
# ---> 99                 Rearrange(f"{from_chars} -> {to_chars}", **axes_len), nn.Linear(self.patch_dim, hidden_size)
#     100             )
#     101         self.position_embeddings = nn.Parameter(torch.zeros(1, self.n_patches, hidden_size))
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in __call__(self, *_args, **_kwargs)
#     441                 OptionalImportError: When you call this method.
#     442             """
# --> 443             raise self._exception
#     444
#     445         def __getitem__(self, item):
#
# /usr/local/lib/python3.9/dist-packages/monai/utils/module.py in optional_import(module, version, version_checker, name, descriptor, version_args, allow_namespace_pkg, as_type)
#     393         actual_cmd = f"import {module}"
#     394     try:
# --> 395         pkg = __import__(module)  # top level module
#     396         the_module = import_module(module)
#     397         if not allow_namespace_pkg:
#
# OptionalImportError: from einops.layers.torch import Rearrange (No module named 'einops').
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # Start training

# %%
max_epochs = 100
val_interval = 1
best_metric = -1
best_metric_epoch = -1
metric_values = []
epoch_loss_values = []
post_pred = Compose([AsDiscrete(argmax = True, to_onehot = 2)])
post_label = Compose([AsDiscrete(to_onehot = 2)])

for epoch in range(max_epochs):
  print("-" * 12)
  print(f"Epoch {epoch + 1}/{max_epochs}")

  # Turn model to "train" mode
  model.train()

  epoch_loss = 0
  step = 0
  for batch_data in train_loader:
    step += 1

    input, label = (
        batch_data["image"].to(device),
        batch_data["label"].to(device),
    )

    # A common pytorch Deep Learning format to train model
    optimizer.zero_grad()
    output = model(input)
    loss = loss_function(output, label)
    loss.backward() # Compute gradient
    optimizer.step() # Update model's parameters

    epoch_loss += loss.item()
    print(f"{step}/{len(dataset) // train_loader.batch_size}, "
          f"train_loss: {loss.item():.4f}")
    
  epoch_loss /= step
  epoch_loss_values.append(epoch_loss)

  print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

  if (epoch + 1) % val_interval == 0:
    # Turn model to "eval" mode
    model.eval() 

    # Disabling gradient calculation is useful for inference, when you are sure that you will not call Tensor.backward(). 
    # It will reduce memory consumption for computations that would otherwise have requires_grad=True
    with torch.no_grad():
      for val_data in val_loader:
        val_input, val_label = (
            val_data["image"].to(device),
            val_data["label"].to(device),
        )
        roi_size = (128, 128, 96)
        sw_batch_size = 1

        # Set AMP for MONAI validation
        val_output = sliding_window_inference(
            val_input, roi_size, sw_batch_size, model
        )
        val_output = [post_pred(i) for i in decollate_batch(val_output)]
        val_label = [post_label(i) for i in decollate_batch(val_label)]

        # Compute metric for current iteration
        dice_metric(y_pred = val_output, y = val_label)

      # Aggregate the final mean dice result
      metric = dice_metric.aggregate().item()

      # Reset the status for the next epoch
      dice_metric.reset()

      metric_values.append(metric)
      if metric > best_metric:
        best_metric = metric
        best_metric_epoch = epoch + 1
        print("saved new best metric model!!!")
        torch.save(model.state_dict(), "best_metric_model.pth")
      
      print(
          f"current epoch: {epoch + 1},"
          f" current mean dice: {metric:.4f},"
          f" best mean dice: {best_metric:.4f},"
          f" at epoch: {best_metric_epoch}"
      )

print(
    f"train completed, best metric: {best_metric:.4f}"
    f" at epoch: {best_metric_epoch}"
)
# Out:
# Streaming output truncated to the last 5000 lines.
# 9/51, train_loss: 0.6964
# 10/51, train_loss: 1.0000
# 11/51, train_loss: 0.8303
# 12/51, train_loss: 0.9661
# 13/51, train_loss: 0.9309
# 14/51, train_loss: 0.8904
# 15/51, train_loss: 0.7226
# 16/51, train_loss: 0.9991
# 17/51, train_loss: 0.9605
# 18/51, train_loss: 1.0000
# 19/51, train_loss: 1.0000
# 20/51, train_loss: 1.0000
# 21/51, train_loss: 0.9994
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.9634
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.9857
# 26/51, train_loss: 0.9935
# 27/51, train_loss: 0.9969
# 28/51, train_loss: 0.9999
# 29/51, train_loss: 1.0000
# 30/51, train_loss: 0.7801
# 31/51, train_loss: 0.9941
# 32/51, train_loss: 0.9796
# 33/51, train_loss: 0.7903
# 34/51, train_loss: 1.0000
# 35/51, train_loss: 0.6754
# 36/51, train_loss: 0.9866
# 37/51, train_loss: 0.9866
# 38/51, train_loss: 0.9776
# 39/51, train_loss: 0.9247
# 40/51, train_loss: 0.9991
# 41/51, train_loss: 0.7638
# 42/51, train_loss: 0.9648
# 43/51, train_loss: 0.7910
# 44/51, train_loss: 0.7513
# 45/51, train_loss: 0.9987
# 46/51, train_loss: 0.5541
# 47/51, train_loss: 0.9976
# 48/51, train_loss: 0.9994
# 49/51, train_loss: 1.0000
# 50/51, train_loss: 0.6805
# 51/51, train_loss: 0.9156
# epoch 10 average loss: 0.9116
# current epoch: 10, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 11/100
# 1/51, train_loss: 0.7087
# 2/51, train_loss: 0.7154
# 3/51, train_loss: 1.0000
# 4/51, train_loss: 0.4769
# 5/51, train_loss: 0.7155
# 6/51, train_loss: 0.9587
# 7/51, train_loss: 0.9547
# 8/51, train_loss: 0.9999
# 9/51, train_loss: 0.9515
# 10/51, train_loss: 0.6420
# 11/51, train_loss: 1.0000
# 12/51, train_loss: 0.8494
# 13/51, train_loss: 0.9367
# 14/51, train_loss: 0.8855
# 15/51, train_loss: 0.7783
# 16/51, train_loss: 0.7662
# 17/51, train_loss: 1.0000
# 18/51, train_loss: 1.0000
# 19/51, train_loss: 0.8332
# 20/51, train_loss: 0.6043
# 21/51, train_loss: 0.9739
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.9435
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.9689
# 26/51, train_loss: 0.9999
# 27/51, train_loss: 0.9130
# 28/51, train_loss: 0.9992
# 29/51, train_loss: 0.5920
# 30/51, train_loss: 0.9867
# 31/51, train_loss: 0.7895
# 32/51, train_loss: 0.7355
# 33/51, train_loss: 0.7812
# 34/51, train_loss: 0.9983
# 35/51, train_loss: 1.0000
# 36/51, train_loss: 1.0000
# 37/51, train_loss: 0.9998
# 38/51, train_loss: 1.0000
# 39/51, train_loss: 0.9631
# 40/51, train_loss: 0.9987
# 41/51, train_loss: 0.7387
# 42/51, train_loss: 0.9761
# 43/51, train_loss: 0.9861
# 44/51, train_loss: 0.9993
# 45/51, train_loss: 0.9612
# 46/51, train_loss: 0.9945
# 47/51, train_loss: 0.9890
# 48/51, train_loss: 0.9064
# 49/51, train_loss: 0.9995
# 50/51, train_loss: 0.9266
# 51/51, train_loss: 0.9724
# epoch 11 average loss: 0.8994
# current epoch: 11, current mean dice: 0.0001, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 12/100
# 1/51, train_loss: 0.9272
# 2/51, train_loss: 0.9472
# 3/51, train_loss: 0.5367
# 4/51, train_loss: 1.0000
# 5/51, train_loss: 0.9964
# 6/51, train_loss: 0.9694
# 7/51, train_loss: 0.9352
# 8/51, train_loss: 0.9684
# 9/51, train_loss: 0.9998
# 10/51, train_loss: 1.0000
# 11/51, train_loss: 1.0000
# 12/51, train_loss: 0.6989
# 13/51, train_loss: 1.0000
# 14/51, train_loss: 0.9997
# 15/51, train_loss: 0.9808
# 16/51, train_loss: 0.8320
# 17/51, train_loss: 0.8640
# 18/51, train_loss: 0.8628
# 19/51, train_loss: 0.7813
# 20/51, train_loss: 0.9935
# 21/51, train_loss: 0.8882
# 22/51, train_loss: 0.9953
# 23/51, train_loss: 0.9929
# 24/51, train_loss: 0.9954
# 25/51, train_loss: 0.7546
# 26/51, train_loss: 0.9065
# 27/51, train_loss: 0.9045
# 28/51, train_loss: 0.5757
# 29/51, train_loss: 0.6857
# 30/51, train_loss: 0.9999
# 31/51, train_loss: 0.9977
# 32/51, train_loss: 0.7520
# 33/51, train_loss: 1.0000
# 34/51, train_loss: 0.7761
# 35/51, train_loss: 0.9990
# 36/51, train_loss: 0.6261
# 37/51, train_loss: 0.9765
# 38/51, train_loss: 0.9047
# 39/51, train_loss: 0.3594
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 0.9777
# 42/51, train_loss: 1.0000
# 43/51, train_loss: 0.4509
# 44/51, train_loss: 0.6587
# 45/51, train_loss: 0.9735
# 46/51, train_loss: 0.9979
# 47/51, train_loss: 0.8228
# 48/51, train_loss: 1.0000
# 49/51, train_loss: 0.9982
# 50/51, train_loss: 0.9936
# 51/51, train_loss: 0.9917
# epoch 12 average loss: 0.8872
# current epoch: 12, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 13/100
# 1/51, train_loss: 0.4326
# 2/51, train_loss: 0.6325
# 3/51, train_loss: 0.5085
# 4/51, train_loss: 0.6932
# 5/51, train_loss: 0.8161
# 6/51, train_loss: 0.6674
# 7/51, train_loss: 1.0000
# 8/51, train_loss: 0.8254
# 9/51, train_loss: 0.8810
# 10/51, train_loss: 0.9987
# 11/51, train_loss: 0.4672
# 12/51, train_loss: 1.0000
# 13/51, train_loss: 0.9817
# 14/51, train_loss: 0.9988
# 15/51, train_loss: 0.9948
# 16/51, train_loss: 0.9893
# 17/51, train_loss: 0.8078
# 18/51, train_loss: 1.0000
# 19/51, train_loss: 1.0000
# 20/51, train_loss: 0.9267
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 0.9471
# 23/51, train_loss: 0.9963
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.5816
# 26/51, train_loss: 0.9550
# 27/51, train_loss: 0.9939
# 28/51, train_loss: 0.7755
# 29/51, train_loss: 0.9171
# 30/51, train_loss: 0.5222
# 31/51, train_loss: 0.4617
# 32/51, train_loss: 1.0000
# 33/51, train_loss: 0.4873
# 34/51, train_loss: 0.9999
# 35/51, train_loss: 0.9848
# 36/51, train_loss: 0.9999
# 37/51, train_loss: 0.4573
# 38/51, train_loss: 0.9306
# 39/51, train_loss: 0.9349
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 0.3631
# 42/51, train_loss: 0.9387
# 43/51, train_loss: 0.7855
# 44/51, train_loss: 0.6213
# 45/51, train_loss: 0.9635
# 46/51, train_loss: 0.9439
# 47/51, train_loss: 0.9984
# 48/51, train_loss: 0.7702
# 49/51, train_loss: 1.0000
# 50/51, train_loss: 0.8630
# 51/51, train_loss: 0.5552
# epoch 13 average loss: 0.8308
# current epoch: 13, current mean dice: 0.0006, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 14/100
# 1/51, train_loss: 1.0000
# 2/51, train_loss: 1.0000
# 3/51, train_loss: 0.9994
# 4/51, train_loss: 0.9965
# 5/51, train_loss: 0.4044
# 6/51, train_loss: 0.4269
# 7/51, train_loss: 0.5751
# 8/51, train_loss: 0.6166
# 9/51, train_loss: 0.5583
# 10/51, train_loss: 0.5660
# 11/51, train_loss: 0.4708
# 12/51, train_loss: 0.9989
# 13/51, train_loss: 0.9978
# 14/51, train_loss: 0.6630
# 15/51, train_loss: 0.9835
# 16/51, train_loss: 1.0000
# 17/51, train_loss: 0.9985
# 18/51, train_loss: 0.9996
# 19/51, train_loss: 0.4546
# 20/51, train_loss: 0.7328
# 21/51, train_loss: 0.7802
# 22/51, train_loss: 0.6402
# 23/51, train_loss: 0.7833
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.9712
# 26/51, train_loss: 0.6656
# 27/51, train_loss: 0.7569
# 28/51, train_loss: 0.5704
# 29/51, train_loss: 0.9094
# 30/51, train_loss: 0.7012
# 31/51, train_loss: 0.4934
# 32/51, train_loss: 0.6081
# 33/51, train_loss: 0.9999
# 34/51, train_loss: 0.2530
# 35/51, train_loss: 0.6075
# 36/51, train_loss: 0.9322
# 37/51, train_loss: 1.0000
# 38/51, train_loss: 0.9900
# 39/51, train_loss: 1.0000
# 40/51, train_loss: 0.4187
# 41/51, train_loss: 1.0000
# 42/51, train_loss: 0.5076
# 43/51, train_loss: 0.9866
# 44/51, train_loss: 0.4595
# 45/51, train_loss: 0.2768
# 46/51, train_loss: 0.5086
# 47/51, train_loss: 0.9571
# 48/51, train_loss: 0.9999
# 49/51, train_loss: 0.9956
# 50/51, train_loss: 0.9996
# 51/51, train_loss: 0.9821
# epoch 14 average loss: 0.7686
# current epoch: 14, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 15/100
# 1/51, train_loss: 0.3727
# 2/51, train_loss: 0.6684
# 3/51, train_loss: 0.9998
# 4/51, train_loss: 1.0000
# 5/51, train_loss: 0.9698
# 6/51, train_loss: 1.0000
# 7/51, train_loss: 0.8773
# 8/51, train_loss: 0.9591
# 9/51, train_loss: 0.9846
# 10/51, train_loss: 0.8719
# 11/51, train_loss: 0.9851
# 12/51, train_loss: 0.8538
# 13/51, train_loss: 0.8739
# 14/51, train_loss: 0.9721
# 15/51, train_loss: 0.8652
# 16/51, train_loss: 0.6634
# 17/51, train_loss: 0.4974
# 18/51, train_loss: 0.4551
# 19/51, train_loss: 0.7667
# 20/51, train_loss: 0.8635
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 0.9958
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.9752
# 26/51, train_loss: 0.6813
# 27/51, train_loss: 1.0000
# 28/51, train_loss: 0.9998
# 29/51, train_loss: 0.5708
# 30/51, train_loss: 0.7442
# 31/51, train_loss: 0.8642
# 32/51, train_loss: 0.7725
# 33/51, train_loss: 0.9183
# 34/51, train_loss: 0.9988
# 35/51, train_loss: 0.9050
# 36/51, train_loss: 0.8387
# 37/51, train_loss: 0.7977
# 38/51, train_loss: 0.6710
# 39/51, train_loss: 0.5513
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 0.3355
# 42/51, train_loss: 0.9441
# 43/51, train_loss: 1.0000
# 44/51, train_loss: 0.9999
# 45/51, train_loss: 0.9294
# 46/51, train_loss: 0.9508
# 47/51, train_loss: 0.5078
# 48/51, train_loss: 0.7702
# 49/51, train_loss: 0.8187
# 50/51, train_loss: 0.4559
# 51/51, train_loss: 0.9975
# epoch 15 average loss: 0.8332
# current epoch: 15, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 16/100
# 1/51, train_loss: 0.8141
# 2/51, train_loss: 0.4901
# 3/51, train_loss: 1.0000
# 4/51, train_loss: 0.9985
# 5/51, train_loss: 0.9240
# 6/51, train_loss: 0.5464
# 7/51, train_loss: 0.4764
# 8/51, train_loss: 0.7606
# 9/51, train_loss: 0.8706
# 10/51, train_loss: 0.4508
# 11/51, train_loss: 1.0000
# 12/51, train_loss: 1.0000
# 13/51, train_loss: 1.0000
# 14/51, train_loss: 0.5693
# 15/51, train_loss: 0.9350
# 16/51, train_loss: 0.4930
# 17/51, train_loss: 0.6160
# 18/51, train_loss: 0.9257
# 19/51, train_loss: 1.0000
# 20/51, train_loss: 0.9619
# 21/51, train_loss: 0.9965
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.8844
# 24/51, train_loss: 0.9993
# 25/51, train_loss: 1.0000
# 26/51, train_loss: 1.0000
# 27/51, train_loss: 0.9861
# 28/51, train_loss: 0.8677
# 29/51, train_loss: 0.6838
# 30/51, train_loss: 0.8307
# 31/51, train_loss: 1.0000
# 32/51, train_loss: 0.9531
# 33/51, train_loss: 0.5211
# 34/51, train_loss: 0.6254
# 35/51, train_loss: 0.9400
# 36/51, train_loss: 0.6685
# 37/51, train_loss: 0.8346
# 38/51, train_loss: 0.5764
# 39/51, train_loss: 0.3927
# 40/51, train_loss: 0.8719
# 41/51, train_loss: 0.3366
# 42/51, train_loss: 0.6897
# 43/51, train_loss: 0.9902
# 44/51, train_loss: 0.9929
# 45/51, train_loss: 0.4997
# 46/51, train_loss: 0.8833
# 47/51, train_loss: 0.4588
# 48/51, train_loss: 0.9960
# 49/51, train_loss: 0.9465
# 50/51, train_loss: 0.5981
# 51/51, train_loss: 0.6750
# epoch 16 average loss: 0.7947
# current epoch: 16, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 17/100
# 1/51, train_loss: 0.6516
# 2/51, train_loss: 0.2715
# 3/51, train_loss: 0.1600
# 4/51, train_loss: 0.9987
# 5/51, train_loss: 0.3747
# 6/51, train_loss: 1.0000
# 7/51, train_loss: 0.9843
# 8/51, train_loss: 0.8745
# 9/51, train_loss: 0.5340
# 10/51, train_loss: 0.9684
# 11/51, train_loss: 0.2972
# 12/51, train_loss: 0.5173
# 13/51, train_loss: 1.0000
# 14/51, train_loss: 0.8495
# 15/51, train_loss: 0.6737
# 16/51, train_loss: 0.4934
# 17/51, train_loss: 0.6150
# 18/51, train_loss: 0.8433
# 19/51, train_loss: 0.8175
# 20/51, train_loss: 0.8265
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 0.5512
# 23/51, train_loss: 0.9888
# 24/51, train_loss: 0.8376
# 25/51, train_loss: 0.7008
# 26/51, train_loss: 0.5050
# 27/51, train_loss: 0.6246
# 28/51, train_loss: 1.0000
# 29/51, train_loss: 0.5894
# 30/51, train_loss: 0.2685
# 31/51, train_loss: 0.4515
# 32/51, train_loss: 0.9719
# 33/51, train_loss: 0.9971
# 34/51, train_loss: 0.8450
# 35/51, train_loss: 0.9883
# 36/51, train_loss: 0.5615
# 37/51, train_loss: 0.6172
# 38/51, train_loss: 0.9842
# 39/51, train_loss: 1.0000
# 40/51, train_loss: 0.9975
# 41/51, train_loss: 0.9550
# 42/51, train_loss: 0.4500
# 43/51, train_loss: 0.3322
# 44/51, train_loss: 0.5185
# 45/51, train_loss: 0.9970
# 46/51, train_loss: 1.0000
# 47/51, train_loss: 0.5278
# 48/51, train_loss: 0.9531
# 49/51, train_loss: 0.9764
# 50/51, train_loss: 0.9998
# 51/51, train_loss: 1.0000
# epoch 17 average loss: 0.7439
# current epoch: 17, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 18/100
# 1/51, train_loss: 0.8608
# 2/51, train_loss: 0.4205
# 3/51, train_loss: 0.8594
# 4/51, train_loss: 0.5752
# 5/51, train_loss: 0.6953
# 6/51, train_loss: 0.7251
# 7/51, train_loss: 0.4872
# 8/51, train_loss: 0.9939
# 9/51, train_loss: 0.6681
# 10/51, train_loss: 0.8098
# 11/51, train_loss: 0.9839
# 12/51, train_loss: 0.2881
# 13/51, train_loss: 0.4127
# 14/51, train_loss: 0.9282
# 15/51, train_loss: 0.6593
# 16/51, train_loss: 1.0000
# 17/51, train_loss: 0.7108
# 18/51, train_loss: 0.4498
# 19/51, train_loss: 0.3515
# 20/51, train_loss: 0.5198
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 0.9999
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 0.9999
# 25/51, train_loss: 0.9965
# 26/51, train_loss: 0.9833
# 27/51, train_loss: 1.0000
# 28/51, train_loss: 0.9984
# 29/51, train_loss: 0.9816
# 30/51, train_loss: 0.9897
# 31/51, train_loss: 0.9763
# 32/51, train_loss: 0.9678
# 33/51, train_loss: 0.9794
# 34/51, train_loss: 0.9646
# 35/51, train_loss: 0.9143
# 36/51, train_loss: 0.9185
# 37/51, train_loss: 1.0000
# 38/51, train_loss: 0.7286
# 39/51, train_loss: 0.9934
# 40/51, train_loss: 0.9267
# 41/51, train_loss: 0.9998
# 42/51, train_loss: 0.9999
# 43/51, train_loss: 0.7465
# 44/51, train_loss: 0.9792
# 45/51, train_loss: 1.0000
# 46/51, train_loss: 0.3384
# 47/51, train_loss: 0.4709
# 48/51, train_loss: 0.6172
# 49/51, train_loss: 0.5469
# 50/51, train_loss: 0.7349
# 51/51, train_loss: 0.6204
# epoch 18 average loss: 0.7995
# current epoch: 18, current mean dice: 0.0007, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 19/100
# 1/51, train_loss: 0.9624
# 2/51, train_loss: 0.8589
# 3/51, train_loss: 0.4379
# 4/51, train_loss: 0.4842
# 5/51, train_loss: 0.9541
# 6/51, train_loss: 0.7870
# 7/51, train_loss: 1.0000
# 8/51, train_loss: 0.8242
# 9/51, train_loss: 0.9999
# 10/51, train_loss: 0.8093
# 11/51, train_loss: 0.7479
# 12/51, train_loss: 0.5350
# 13/51, train_loss: 0.9892
# 14/51, train_loss: 0.9989
# 15/51, train_loss: 0.6519
# 16/51, train_loss: 0.9992
# 17/51, train_loss: 0.2523
# 18/51, train_loss: 0.4661
# 19/51, train_loss: 0.9340
# 20/51, train_loss: 1.0000
# 21/51, train_loss: 0.8666
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.9324
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.8076
# 26/51, train_loss: 0.5881
# 27/51, train_loss: 0.5456
# 28/51, train_loss: 0.9303
# 29/51, train_loss: 0.9416
# 30/51, train_loss: 0.9999
# 31/51, train_loss: 1.0000
# 32/51, train_loss: 0.3046
# 33/51, train_loss: 0.7252
# 34/51, train_loss: 1.0000
# 35/51, train_loss: 1.0000
# 36/51, train_loss: 0.4476
# 37/51, train_loss: 0.3095
# 38/51, train_loss: 0.2752
# 39/51, train_loss: 0.9889
# 40/51, train_loss: 0.6900
# 41/51, train_loss: 0.5908
# 42/51, train_loss: 0.2665
# 43/51, train_loss: 0.3300
# 44/51, train_loss: 0.2833
# 45/51, train_loss: 0.4673
# 46/51, train_loss: 0.6433
# 47/51, train_loss: 0.9145
# 48/51, train_loss: 0.4706
# 49/51, train_loss: 0.9998
# 50/51, train_loss: 0.9724
# 51/51, train_loss: 0.6185
# epoch 19 average loss: 0.7373
# current epoch: 19, current mean dice: 0.0004, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 20/100
# 1/51, train_loss: 0.3344
# 2/51, train_loss: 1.0000
# 3/51, train_loss: 0.4597
# 4/51, train_loss: 0.4365
# 5/51, train_loss: 0.2914
# 6/51, train_loss: 0.5180
# 7/51, train_loss: 0.5840
# 8/51, train_loss: 0.3405
# 9/51, train_loss: 0.4796
# 10/51, train_loss: 1.0000
# 11/51, train_loss: 1.0000
# 12/51, train_loss: 0.4912
# 13/51, train_loss: 0.3763
# 14/51, train_loss: 1.0000
# 15/51, train_loss: 0.9398
# 16/51, train_loss: 1.0000
# 17/51, train_loss: 0.6370
# 18/51, train_loss: 0.5728
# 19/51, train_loss: 0.4824
# 20/51, train_loss: 0.4498
# 21/51, train_loss: 0.7961
# 22/51, train_loss: 0.9817
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 1.0000
# 26/51, train_loss: 0.4725
# 27/51, train_loss: 0.5317
# 28/51, train_loss: 0.8558
# 29/51, train_loss: 0.9194
# 30/51, train_loss: 0.8829
# 31/51, train_loss: 0.9972
# 32/51, train_loss: 0.4757
# 33/51, train_loss: 0.7020
# 34/51, train_loss: 0.6385
# 35/51, train_loss: 0.9996
# 36/51, train_loss: 0.8778
# 37/51, train_loss: 0.2797
# 38/51, train_loss: 0.2487
# 39/51, train_loss: 0.9178
# 40/51, train_loss: 0.4975
# 41/51, train_loss: 0.3001
# 42/51, train_loss: 0.8690
# 43/51, train_loss: 1.0000
# 44/51, train_loss: 0.9990
# 45/51, train_loss: 0.9962
# 46/51, train_loss: 0.4503
# 47/51, train_loss: 0.3915
# 48/51, train_loss: 0.5472
# 49/51, train_loss: 0.9500
# 50/51, train_loss: 0.6698
# 51/51, train_loss: 0.9999
# epoch 20 average loss: 0.6988
# current epoch: 20, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 21/100
# 1/51, train_loss: 0.2080
# 2/51, train_loss: 0.9974
# 3/51, train_loss: 0.9723
# 4/51, train_loss: 1.0000
# 5/51, train_loss: 0.3023
# 6/51, train_loss: 0.3812
# 7/51, train_loss: 0.7530
# 8/51, train_loss: 0.9681
# 9/51, train_loss: 0.9995
# 10/51, train_loss: 0.9708
# 11/51, train_loss: 0.5400
# 12/51, train_loss: 0.6860
# 13/51, train_loss: 0.7375
# 14/51, train_loss: 0.3597
# 15/51, train_loss: 1.0000
# 16/51, train_loss: 1.0000
# 17/51, train_loss: 0.7135
# 18/51, train_loss: 0.5117
# 19/51, train_loss: 0.8920
# 20/51, train_loss: 0.6018
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 0.6942
# 25/51, train_loss: 0.5451
# 26/51, train_loss: 0.6153
# 27/51, train_loss: 0.3023
# 28/51, train_loss: 0.5820
# 29/51, train_loss: 0.9203
# 30/51, train_loss: 0.2742
# 31/51, train_loss: 0.2364
# 32/51, train_loss: 0.9146
# 33/51, train_loss: 0.7731
# 34/51, train_loss: 0.7462
# 35/51, train_loss: 1.0000
# 36/51, train_loss: 0.3779
# 37/51, train_loss: 1.0000
# 38/51, train_loss: 0.2311
# 39/51, train_loss: 0.9905
# 40/51, train_loss: 0.3953
# 41/51, train_loss: 0.9839
# 42/51, train_loss: 0.8131
# 43/51, train_loss: 0.9771
# 44/51, train_loss: 1.0000
# 45/51, train_loss: 0.2706
# 46/51, train_loss: 0.3221
# 47/51, train_loss: 0.4962
# 48/51, train_loss: 0.6479
# 49/51, train_loss: 0.5798
# 50/51, train_loss: 0.9424
# 51/51, train_loss: 0.9994
# epoch 21 average loss: 0.7103
# current epoch: 21, current mean dice: 0.0001, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 22/100
# 1/51, train_loss: 0.8830
# 2/51, train_loss: 0.9831
# 3/51, train_loss: 0.2026
# 4/51, train_loss: 0.3474
# 5/51, train_loss: 0.9990
# 6/51, train_loss: 0.6013
# 7/51, train_loss: 0.7211
# 8/51, train_loss: 0.3185
# 9/51, train_loss: 0.5574
# 10/51, train_loss: 0.8622
# 11/51, train_loss: 0.4671
# 12/51, train_loss: 0.4509
# 13/51, train_loss: 0.4941
# 14/51, train_loss: 1.0000
# 15/51, train_loss: 0.4188
# 16/51, train_loss: 0.5342
# 17/51, train_loss: 0.7940
# 18/51, train_loss: 0.2863
# 19/51, train_loss: 0.3571
# 20/51, train_loss: 0.7812
# 21/51, train_loss: 0.9969
# 22/51, train_loss: 0.9584
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.9994
# 26/51, train_loss: 0.4951
# 27/51, train_loss: 0.2713
# 28/51, train_loss: 0.9994
# 29/51, train_loss: 0.4067
# 30/51, train_loss: 0.9803
# 31/51, train_loss: 0.5724
# 32/51, train_loss: 0.9519
# 33/51, train_loss: 1.0000
# 34/51, train_loss: 0.4130
# 35/51, train_loss: 0.9750
# 36/51, train_loss: 0.9337
# 37/51, train_loss: 1.0000
# 38/51, train_loss: 0.4108
# 39/51, train_loss: 0.9800
# 40/51, train_loss: 0.6270
# 41/51, train_loss: 0.6740
# 42/51, train_loss: 0.4286
# 43/51, train_loss: 0.6503
# 44/51, train_loss: 0.7966
# 45/51, train_loss: 0.4652
# 46/51, train_loss: 0.2883
# 47/51, train_loss: 0.6039
# 48/51, train_loss: 0.6678
# 49/51, train_loss: 0.5953
# 50/51, train_loss: 0.6763
# 51/51, train_loss: 0.9453
# epoch 22 average loss: 0.6828
# current epoch: 22, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 23/100
# 1/51, train_loss: 0.3200
# 2/51, train_loss: 0.2586
# 3/51, train_loss: 0.3351
# 4/51, train_loss: 0.7660
# 5/51, train_loss: 0.4524
# 6/51, train_loss: 0.9531
# 7/51, train_loss: 0.5496
# 8/51, train_loss: 0.5169
# 9/51, train_loss: 0.8732
# 10/51, train_loss: 0.3236
# 11/51, train_loss: 0.6800
# 12/51, train_loss: 0.9970
# 13/51, train_loss: 0.7160
# 14/51, train_loss: 0.4232
# 15/51, train_loss: 0.4987
# 16/51, train_loss: 0.5878
# 17/51, train_loss: 0.4695
# 18/51, train_loss: 1.0000
# 19/51, train_loss: 0.2998
# 20/51, train_loss: 0.4629
# 21/51, train_loss: 0.4709
# 22/51, train_loss: 0.4671
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 0.5929
# 25/51, train_loss: 0.9275
# 26/51, train_loss: 0.5030
# 27/51, train_loss: 0.3297
# 28/51, train_loss: 0.4280
# 29/51, train_loss: 0.9621
# 30/51, train_loss: 0.3895
# 31/51, train_loss: 0.9268
# 32/51, train_loss: 1.0000
# 33/51, train_loss: 0.9630
# 34/51, train_loss: 0.8374
# 35/51, train_loss: 0.7708
# 36/51, train_loss: 0.9182
# 37/51, train_loss: 1.0000
# 38/51, train_loss: 0.7678
# 39/51, train_loss: 0.2736
# 40/51, train_loss: 0.7122
# 41/51, train_loss: 0.8752
# 42/51, train_loss: 0.1738
# 43/51, train_loss: 0.3586
# 44/51, train_loss: 0.3202
# 45/51, train_loss: 0.9987
# 46/51, train_loss: 0.8498
# 47/51, train_loss: 0.2282
# 48/51, train_loss: 0.4693
# 49/51, train_loss: 1.0000
# 50/51, train_loss: 0.9353
# 51/51, train_loss: 0.4631
# epoch 23 average loss: 0.6352
# current epoch: 23, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 24/100
# 1/51, train_loss: 0.8271
# 2/51, train_loss: 0.4599
# 3/51, train_loss: 0.9118
# 4/51, train_loss: 0.8493
# 5/51, train_loss: 0.4754
# 6/51, train_loss: 0.4470
# 7/51, train_loss: 0.5200
# 8/51, train_loss: 0.7107
# 9/51, train_loss: 0.9507
# 10/51, train_loss: 0.2949
# 11/51, train_loss: 0.4483
# 12/51, train_loss: 0.5782
# 13/51, train_loss: 0.3565
# 14/51, train_loss: 0.4816
# 15/51, train_loss: 0.3179
# 16/51, train_loss: 0.2990
# 17/51, train_loss: 1.0000
# 18/51, train_loss: 0.5299
# 19/51, train_loss: 0.7441
# 20/51, train_loss: 1.0000
# 21/51, train_loss: 0.6351
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.7758
# 24/51, train_loss: 0.5798
# 25/51, train_loss: 0.4679
# 26/51, train_loss: 1.0000
# 27/51, train_loss: 0.7901
# 28/51, train_loss: 1.0000
# 29/51, train_loss: 0.9072
# 30/51, train_loss: 0.9994
# 31/51, train_loss: 0.4628
# 32/51, train_loss: 0.4591
# 33/51, train_loss: 0.7933
# 34/51, train_loss: 0.8930
# 35/51, train_loss: 1.0000
# 36/51, train_loss: 0.4512
# 37/51, train_loss: 0.2606
# 38/51, train_loss: 0.9164
# 39/51, train_loss: 0.9915
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 0.3370
# 42/51, train_loss: 0.3045
# 43/51, train_loss: 0.6151
# 44/51, train_loss: 0.8388
# 45/51, train_loss: 0.9998
# 46/51, train_loss: 0.8813
# 47/51, train_loss: 0.3389
# 48/51, train_loss: 0.4198
# 49/51, train_loss: 0.7318
# 50/51, train_loss: 0.7838
# 51/51, train_loss: 0.4835
# epoch 24 average loss: 0.6729
# current epoch: 24, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 25/100
# 1/51, train_loss: 0.7731
# 2/51, train_loss: 0.4934
# 3/51, train_loss: 0.9319
# 4/51, train_loss: 0.8432
# 5/51, train_loss: 0.8863
# 6/51, train_loss: 0.9232
# 7/51, train_loss: 0.6229
# 8/51, train_loss: 0.3986
# 9/51, train_loss: 0.9961
# 10/51, train_loss: 0.2556
# 11/51, train_loss: 0.2588
# 12/51, train_loss: 0.8668
# 13/51, train_loss: 0.8732
# 14/51, train_loss: 0.3920
# 15/51, train_loss: 1.0000
# 16/51, train_loss: 1.0000
# 17/51, train_loss: 0.7687
# 18/51, train_loss: 0.5288
# 19/51, train_loss: 0.4467
# 20/51, train_loss: 0.7726
# 21/51, train_loss: 0.9999
# 22/51, train_loss: 0.5747
# 23/51, train_loss: 0.3364
# 24/51, train_loss: 0.5380
# 25/51, train_loss: 0.8224
# 26/51, train_loss: 0.3002
# 27/51, train_loss: 1.0000
# 28/51, train_loss: 0.7075
# 29/51, train_loss: 0.3727
# 30/51, train_loss: 0.5373
# 31/51, train_loss: 0.6975
# 32/51, train_loss: 0.8562
# 33/51, train_loss: 0.5650
# 34/51, train_loss: 0.9998
# 35/51, train_loss: 0.4977
# 36/51, train_loss: 0.6600
# 37/51, train_loss: 0.6700
# 38/51, train_loss: 0.3165
# 39/51, train_loss: 0.9977
# 40/51, train_loss: 0.7153
# 41/51, train_loss: 1.0000
# 42/51, train_loss: 1.0000
# 43/51, train_loss: 0.2724
# 44/51, train_loss: 0.5848
# 45/51, train_loss: 0.4166
# 46/51, train_loss: 0.3165
# 47/51, train_loss: 0.4050
# 48/51, train_loss: 0.2174
# 49/51, train_loss: 0.6052
# 50/51, train_loss: 0.2406
# 51/51, train_loss: 0.6378
# epoch 25 average loss: 0.6450
# current epoch: 25, current mean dice: 0.0008, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 26/100
# 1/51, train_loss: 0.3811
# 2/51, train_loss: 0.3566
# 3/51, train_loss: 0.3006
# 4/51, train_loss: 0.3449
# 5/51, train_loss: 0.8026
# 6/51, train_loss: 0.4282
# 7/51, train_loss: 1.0000
# 8/51, train_loss: 0.7792
# 9/51, train_loss: 0.7193
# 10/51, train_loss: 0.4135
# 11/51, train_loss: 1.0000
# 12/51, train_loss: 0.8991
# 13/51, train_loss: 0.5525
# 14/51, train_loss: 0.8334
# 15/51, train_loss: 0.9730
# 16/51, train_loss: 0.6291
# 17/51, train_loss: 0.5648
# 18/51, train_loss: 0.5523
# 19/51, train_loss: 0.4849
# 20/51, train_loss: 0.8373
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 0.9642
# 23/51, train_loss: 0.6521
# 24/51, train_loss: 0.3405
# 25/51, train_loss: 0.4143
# 26/51, train_loss: 0.6813
# 27/51, train_loss: 0.7458
# 28/51, train_loss: 0.4649
# 29/51, train_loss: 0.4517
# 30/51, train_loss: 0.4465
# 31/51, train_loss: 0.4016
# 32/51, train_loss: 0.9901
# 33/51, train_loss: 0.4894
# 34/51, train_loss: 0.5844
# 35/51, train_loss: 0.3143
# 36/51, train_loss: 0.9269
# 37/51, train_loss: 0.2771
# 38/51, train_loss: 1.0000
# 39/51, train_loss: 0.3941
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 0.9703
# 42/51, train_loss: 0.8096
# 43/51, train_loss: 0.1571
# 44/51, train_loss: 0.7745
# 45/51, train_loss: 0.1635
# 46/51, train_loss: 0.9554
# 47/51, train_loss: 0.4312
# 48/51, train_loss: 1.0000
# 49/51, train_loss: 0.8572
# 50/51, train_loss: 0.4724
# 51/51, train_loss: 0.5814
# epoch 26 average loss: 0.6385
# current epoch: 26, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 27/100
# 1/51, train_loss: 0.4144
# 2/51, train_loss: 0.6976
# 3/51, train_loss: 0.5938
# 4/51, train_loss: 1.0000
# 5/51, train_loss: 0.4050
# 6/51, train_loss: 0.3142
# 7/51, train_loss: 0.4814
# 8/51, train_loss: 0.5193
# 9/51, train_loss: 0.4554
# 10/51, train_loss: 0.2079
# 11/51, train_loss: 0.3416
# 12/51, train_loss: 0.3234
# 13/51, train_loss: 1.0000
# 14/51, train_loss: 0.3149
# 15/51, train_loss: 0.2735
# 16/51, train_loss: 0.3128
# 17/51, train_loss: 1.0000
# 18/51, train_loss: 0.3168
# 19/51, train_loss: 0.3804
# 20/51, train_loss: 1.0000
# 21/51, train_loss: 0.5005
# 22/51, train_loss: 0.3487
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.6728
# 26/51, train_loss: 0.5769
# 27/51, train_loss: 0.6266
# 28/51, train_loss: 0.9149
# 29/51, train_loss: 0.9999
# 30/51, train_loss: 0.3439
# 31/51, train_loss: 1.0000
# 32/51, train_loss: 0.8538
# 33/51, train_loss: 0.7994
# 34/51, train_loss: 0.9573
# 35/51, train_loss: 0.9176
# 36/51, train_loss: 0.2676
# 37/51, train_loss: 0.3461
# 38/51, train_loss: 0.2238
# 39/51, train_loss: 0.3528
# 40/51, train_loss: 0.9993
# 41/51, train_loss: 0.3481
# 42/51, train_loss: 0.4209
# 43/51, train_loss: 0.3877
# 44/51, train_loss: 0.3552
# 45/51, train_loss: 0.3871
# 46/51, train_loss: 0.2963
# 47/51, train_loss: 0.8874
# 48/51, train_loss: 0.5119
# 49/51, train_loss: 0.7792
# 50/51, train_loss: 0.4759
# 51/51, train_loss: 0.8400
# epoch 27 average loss: 0.5832
# current epoch: 27, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 28/100
# 1/51, train_loss: 0.7957
# 2/51, train_loss: 0.2702
# 3/51, train_loss: 0.9904
# 4/51, train_loss: 0.3973
# 5/51, train_loss: 0.9256
# 6/51, train_loss: 0.4756
# 7/51, train_loss: 0.8663
# 8/51, train_loss: 0.4069
# 9/51, train_loss: 0.3186
# 10/51, train_loss: 0.5782
# 11/51, train_loss: 0.9975
# 12/51, train_loss: 0.9286
# 13/51, train_loss: 0.8190
# 14/51, train_loss: 0.4880
# 15/51, train_loss: 0.5762
# 16/51, train_loss: 0.2623
# 17/51, train_loss: 0.5150
# 18/51, train_loss: 0.9439
# 19/51, train_loss: 0.3914
# 20/51, train_loss: 0.4809
# 21/51, train_loss: 0.9813
# 22/51, train_loss: 0.3985
# 23/51, train_loss: 0.7217
# 24/51, train_loss: 0.2342
# 25/51, train_loss: 0.3761
# 26/51, train_loss: 0.4913
# 27/51, train_loss: 0.9976
# 28/51, train_loss: 1.0000
# 29/51, train_loss: 0.2955
# 30/51, train_loss: 0.3704
# 31/51, train_loss: 0.6211
# 32/51, train_loss: 0.2067
# 33/51, train_loss: 0.2757
# 34/51, train_loss: 0.6682
# 35/51, train_loss: 0.9990
# 36/51, train_loss: 0.2409
# 37/51, train_loss: 0.7841
# 38/51, train_loss: 0.2706
# 39/51, train_loss: 0.6254
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 1.0000
# 42/51, train_loss: 0.2992
# 43/51, train_loss: 0.2711
# 44/51, train_loss: 0.3149
# 45/51, train_loss: 0.3526
# 46/51, train_loss: 0.3228
# 47/51, train_loss: 0.8110
# 48/51, train_loss: 1.0000
# 49/51, train_loss: 0.8626
# 50/51, train_loss: 0.4886
# 51/51, train_loss: 0.4476
# epoch 28 average loss: 0.5913
# current epoch: 28, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 29/100
# 1/51, train_loss: 0.2495
# 2/51, train_loss: 0.2090
# 3/51, train_loss: 0.2803
# 4/51, train_loss: 0.9989
# 5/51, train_loss: 0.3778
# 6/51, train_loss: 0.6847
# 7/51, train_loss: 0.2803
# 8/51, train_loss: 0.7757
# 9/51, train_loss: 0.9982
# 10/51, train_loss: 0.5869
# 11/51, train_loss: 0.4537
# 12/51, train_loss: 0.4956
# 13/51, train_loss: 0.8557
# 14/51, train_loss: 0.6028
# 15/51, train_loss: 0.3760
# 16/51, train_loss: 0.4929
# 17/51, train_loss: 0.3651
# 18/51, train_loss: 0.2736
# 19/51, train_loss: 0.2928
# 20/51, train_loss: 0.3982
# 21/51, train_loss: 0.9997
# 22/51, train_loss: 0.4023
# 23/51, train_loss: 0.7024
# 24/51, train_loss: 0.4298
# 25/51, train_loss: 0.8785
# 26/51, train_loss: 0.7178
# 27/51, train_loss: 0.2923
# 28/51, train_loss: 0.3198
# 29/51, train_loss: 1.0000
# 30/51, train_loss: 0.6280
# 31/51, train_loss: 0.4411
# 32/51, train_loss: 0.8496
# 33/51, train_loss: 0.3656
# 34/51, train_loss: 0.7328
# 35/51, train_loss: 0.4380
# 36/51, train_loss: 0.9284
# 37/51, train_loss: 0.5377
# 38/51, train_loss: 0.8048
# 39/51, train_loss: 0.9413
# 40/51, train_loss: 0.4801
# 41/51, train_loss: 0.3283
# 42/51, train_loss: 0.9885
# 43/51, train_loss: 0.4058
# 44/51, train_loss: 0.2832
# 45/51, train_loss: 1.0000
# 46/51, train_loss: 0.7278
# 47/51, train_loss: 0.6025
# 48/51, train_loss: 0.1978
# 49/51, train_loss: 1.0000
# 50/51, train_loss: 0.7667
# 51/51, train_loss: 0.8592
# epoch 29 average loss: 0.5902
# current epoch: 29, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 30/100
# 1/51, train_loss: 0.3024
# 2/51, train_loss: 0.3846
# 3/51, train_loss: 0.3138
# 4/51, train_loss: 0.7509
# 5/51, train_loss: 0.2139
# 6/51, train_loss: 0.7978
# 7/51, train_loss: 0.9998
# 8/51, train_loss: 0.6670
# 9/51, train_loss: 0.9085
# 10/51, train_loss: 1.0000
# 11/51, train_loss: 0.4042
# 12/51, train_loss: 0.5232
# 13/51, train_loss: 0.4994
# 14/51, train_loss: 0.3940
# 15/51, train_loss: 0.9919
# 16/51, train_loss: 0.9971
# 17/51, train_loss: 0.2867
# 18/51, train_loss: 0.6698
# 19/51, train_loss: 0.3702
# 20/51, train_loss: 0.3806
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 0.3563
# 23/51, train_loss: 0.5238
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.9361
# 26/51, train_loss: 0.6441
# 27/51, train_loss: 0.5359
# 28/51, train_loss: 0.3313
# 29/51, train_loss: 0.2483
# 30/51, train_loss: 0.6732
# 31/51, train_loss: 0.6256
# 32/51, train_loss: 0.7580
# 33/51, train_loss: 0.4233
# 34/51, train_loss: 1.0000
# 35/51, train_loss: 0.4542
# 36/51, train_loss: 1.0000
# 37/51, train_loss: 0.3550
# 38/51, train_loss: 0.4927
# 39/51, train_loss: 0.4776
# 40/51, train_loss: 0.5744
# 41/51, train_loss: 0.9954
# 42/51, train_loss: 0.4269
# 43/51, train_loss: 0.5299
# 44/51, train_loss: 0.8964
# 45/51, train_loss: 0.2481
# 46/51, train_loss: 0.2045
# 47/51, train_loss: 1.0000
# 48/51, train_loss: 0.4357
# 49/51, train_loss: 0.6569
# 50/51, train_loss: 0.2173
# 51/51, train_loss: 0.9942
# epoch 30 average loss: 0.6053
# current epoch: 30, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 31/100
# 1/51, train_loss: 0.3804
# 2/51, train_loss: 0.1975
# 3/51, train_loss: 0.6276
# 4/51, train_loss: 0.8381
# 5/51, train_loss: 0.7196
# 6/51, train_loss: 0.4161
# 7/51, train_loss: 0.3565
# 8/51, train_loss: 0.2865
# 9/51, train_loss: 0.6623
# 10/51, train_loss: 0.6418
# 11/51, train_loss: 0.5162
# 12/51, train_loss: 0.3914
# 13/51, train_loss: 0.9053
# 14/51, train_loss: 0.7374
# 15/51, train_loss: 0.7735
# 16/51, train_loss: 0.3133
# 17/51, train_loss: 0.3243
# 18/51, train_loss: 0.3029
# 19/51, train_loss: 0.3382
# 20/51, train_loss: 0.3942
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 0.4796
# 23/51, train_loss: 0.2911
# 24/51, train_loss: 0.9990
# 25/51, train_loss: 0.6823
# 26/51, train_loss: 0.6508
# 27/51, train_loss: 0.5872
# 28/51, train_loss: 0.9999
# 29/51, train_loss: 1.0000
# 30/51, train_loss: 0.8532
# 31/51, train_loss: 0.7605
# 32/51, train_loss: 0.5080
# 33/51, train_loss: 0.3384
# 34/51, train_loss: 0.7948
# 35/51, train_loss: 0.9416
# 36/51, train_loss: 0.7282
# 37/51, train_loss: 0.2918
# 38/51, train_loss: 0.9243
# 39/51, train_loss: 0.2068
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 1.0000
# 42/51, train_loss: 1.0000
# 43/51, train_loss: 0.7467
# 44/51, train_loss: 0.9998
# 45/51, train_loss: 0.3163
# 46/51, train_loss: 0.2539
# 47/51, train_loss: 0.6676
# 48/51, train_loss: 0.4062
# 49/51, train_loss: 0.9995
# 50/51, train_loss: 0.2535
# 51/51, train_loss: 0.3985
# epoch 31 average loss: 0.6118
# current epoch: 31, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 32/100
# 1/51, train_loss: 0.2101
# 2/51, train_loss: 0.4256
# 3/51, train_loss: 0.4067
# 4/51, train_loss: 0.7072
# 5/51, train_loss: 0.9985
# 6/51, train_loss: 0.9723
# 7/51, train_loss: 0.2972
# 8/51, train_loss: 0.3607
# 9/51, train_loss: 1.0000
# 10/51, train_loss: 0.3946
# 11/51, train_loss: 0.2689
# 12/51, train_loss: 0.3432
# 13/51, train_loss: 0.3854
# 14/51, train_loss: 1.0000
# 15/51, train_loss: 0.3472
# 16/51, train_loss: 1.0000
# 17/51, train_loss: 0.6608
# 18/51, train_loss: 0.5800
# 19/51, train_loss: 0.6176
# 20/51, train_loss: 0.3470
# 21/51, train_loss: 0.9384
# 22/51, train_loss: 0.5105
# 23/51, train_loss: 0.3671
# 24/51, train_loss: 0.9157
# 25/51, train_loss: 0.2826
# 26/51, train_loss: 0.8886
# 27/51, train_loss: 0.6729
# 28/51, train_loss: 0.9975
# 29/51, train_loss: 0.8449
# 30/51, train_loss: 0.7482
# 31/51, train_loss: 0.7978
# 32/51, train_loss: 0.2944
# 33/51, train_loss: 0.5622
# 34/51, train_loss: 0.3107
# 35/51, train_loss: 1.0000
# 36/51, train_loss: 0.4113
# 37/51, train_loss: 0.1900
# 38/51, train_loss: 0.3313
# 39/51, train_loss: 0.7004
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 0.2412
# 42/51, train_loss: 0.5931
# 43/51, train_loss: 0.3191
# 44/51, train_loss: 0.3696
# 45/51, train_loss: 0.5826
# 46/51, train_loss: 0.2345
# 47/51, train_loss: 0.1986
# 48/51, train_loss: 0.2432
# 49/51, train_loss: 0.2645
# 50/51, train_loss: 0.3874
# 51/51, train_loss: 0.4162
# epoch 32 average loss: 0.5478
# current epoch: 32, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 33/100
# 1/51, train_loss: 0.3546
# 2/51, train_loss: 0.9976
# 3/51, train_loss: 0.2462
# 4/51, train_loss: 0.3763
# 5/51, train_loss: 0.4403
# 6/51, train_loss: 0.6197
# 7/51, train_loss: 0.5365
# 8/51, train_loss: 0.3049
# 9/51, train_loss: 0.9279
# 10/51, train_loss: 0.9042
# 11/51, train_loss: 0.7455
# 12/51, train_loss: 0.4133
# 13/51, train_loss: 0.5171
# 14/51, train_loss: 0.3168
# 15/51, train_loss: 0.7701
# 16/51, train_loss: 0.4040
# 17/51, train_loss: 1.0000
# 18/51, train_loss: 0.4232
# 19/51, train_loss: 0.9182
# 20/51, train_loss: 0.3532
# 21/51, train_loss: 0.3189
# 22/51, train_loss: 0.4474
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 0.9997
# 25/51, train_loss: 0.4767
# 26/51, train_loss: 1.0000
# 27/51, train_loss: 0.3743
# 28/51, train_loss: 0.5598
# 29/51, train_loss: 0.5291
# 30/51, train_loss: 0.5110
# 31/51, train_loss: 0.3038
# 32/51, train_loss: 0.2723
# 33/51, train_loss: 0.5515
# 34/51, train_loss: 0.4902
# 35/51, train_loss: 0.5584
# 36/51, train_loss: 0.3106
# 37/51, train_loss: 0.9834
# 38/51, train_loss: 0.3249
# 39/51, train_loss: 0.2230
# 40/51, train_loss: 0.3219
# 41/51, train_loss: 1.0000
# 42/51, train_loss: 0.7082
# 43/51, train_loss: 0.3729
# 44/51, train_loss: 0.3151
# 45/51, train_loss: 1.0000
# 46/51, train_loss: 0.2467
# 47/51, train_loss: 0.2715
# 48/51, train_loss: 1.0000
# 49/51, train_loss: 0.7063
# 50/51, train_loss: 0.7707
# 51/51, train_loss: 0.4264
# epoch 33 average loss: 0.5675
# current epoch: 33, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 34/100
# 1/51, train_loss: 0.1826
# 2/51, train_loss: 0.3694
# 3/51, train_loss: 0.2631
# 4/51, train_loss: 0.6445
# 5/51, train_loss: 1.0000
# 6/51, train_loss: 0.5360
# 7/51, train_loss: 0.4944
# 8/51, train_loss: 0.3272
# 9/51, train_loss: 0.2401
# 10/51, train_loss: 1.0000
# 11/51, train_loss: 0.2439
# 12/51, train_loss: 0.4212
# 13/51, train_loss: 0.3637
# 14/51, train_loss: 0.3552
# 15/51, train_loss: 0.2169
# 16/51, train_loss: 0.4137
# 17/51, train_loss: 0.9471
# 18/51, train_loss: 1.0000
# 19/51, train_loss: 1.0000
# 20/51, train_loss: 0.5696
# 21/51, train_loss: 0.4453
# 22/51, train_loss: 0.9573
# 23/51, train_loss: 0.3997
# 24/51, train_loss: 0.4868
# 25/51, train_loss: 0.3072
# 26/51, train_loss: 0.3016
# 27/51, train_loss: 0.4491
# 28/51, train_loss: 0.2972
# 29/51, train_loss: 0.7859
# 30/51, train_loss: 0.3500
# 31/51, train_loss: 0.8293
# 32/51, train_loss: 0.8444
# 33/51, train_loss: 0.9053
# 34/51, train_loss: 0.8597
# 35/51, train_loss: 0.6459
# 36/51, train_loss: 0.5562
# 37/51, train_loss: 1.0000
# 38/51, train_loss: 0.3143
# 39/51, train_loss: 0.1775
# 40/51, train_loss: 0.8686
# 41/51, train_loss: 0.9984
# 42/51, train_loss: 0.3068
# 43/51, train_loss: 0.1788
# 44/51, train_loss: 0.6827
# 45/51, train_loss: 0.5234
# 46/51, train_loss: 0.5696
# 47/51, train_loss: 0.2090
# 48/51, train_loss: 1.0000
# 49/51, train_loss: 0.8333
# 50/51, train_loss: 0.6483
# 51/51, train_loss: 0.2803
# epoch 34 average loss: 0.5608
# current epoch: 34, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 35/100
# 1/51, train_loss: 0.2972
# 2/51, train_loss: 0.1933
# 3/51, train_loss: 0.1920
# 4/51, train_loss: 0.3135
# 5/51, train_loss: 0.3610
# 6/51, train_loss: 0.3280
# 7/51, train_loss: 0.4746
# 8/51, train_loss: 0.5813
# 9/51, train_loss: 0.9998
# 10/51, train_loss: 0.6407
# 11/51, train_loss: 0.4453
# 12/51, train_loss: 0.6264
# 13/51, train_loss: 0.9788
# 14/51, train_loss: 0.3872
# 15/51, train_loss: 0.3765
# 16/51, train_loss: 0.5716
# 17/51, train_loss: 0.3318
# 18/51, train_loss: 0.2655
# 19/51, train_loss: 0.3978
# 20/51, train_loss: 0.6839
# 21/51, train_loss: 0.9184
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.1828
# 24/51, train_loss: 0.5025
# 25/51, train_loss: 0.6554
# 26/51, train_loss: 0.8630
# 27/51, train_loss: 0.5280
# 28/51, train_loss: 0.2627
# 29/51, train_loss: 0.4303
# 30/51, train_loss: 1.0000
# 31/51, train_loss: 0.1809
# 32/51, train_loss: 0.2143
# 33/51, train_loss: 1.0000
# 34/51, train_loss: 0.8586
# 35/51, train_loss: 0.8351
# 36/51, train_loss: 0.6312
# 37/51, train_loss: 0.4145
# 38/51, train_loss: 0.4353
# 39/51, train_loss: 0.9999
# 40/51, train_loss: 0.5981
# 41/51, train_loss: 0.2568
# 42/51, train_loss: 0.2502
# 43/51, train_loss: 1.0000
# 44/51, train_loss: 0.2371
# 45/51, train_loss: 0.8443
# 46/51, train_loss: 0.2961
# 47/51, train_loss: 0.3295
# 48/51, train_loss: 1.0000
# 49/51, train_loss: 0.7722
# 50/51, train_loss: 0.4481
# 51/51, train_loss: 0.4800
# epoch 35 average loss: 0.5465
# current epoch: 35, current mean dice: 0.0002, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 36/100
# 1/51, train_loss: 0.3172
# 2/51, train_loss: 0.6347
# 3/51, train_loss: 0.6604
# 4/51, train_loss: 0.8047
# 5/51, train_loss: 0.2722
# 6/51, train_loss: 1.0000
# 7/51, train_loss: 1.0000
# 8/51, train_loss: 0.8105
# 9/51, train_loss: 0.6308
# 10/51, train_loss: 0.4416
# 11/51, train_loss: 0.1933
# 12/51, train_loss: 0.7617
# 13/51, train_loss: 0.5235
# 14/51, train_loss: 0.3999
# 15/51, train_loss: 0.5511
# 16/51, train_loss: 0.2519
# 17/51, train_loss: 1.0000
# 18/51, train_loss: 0.3556
# 19/51, train_loss: 0.5522
# 20/51, train_loss: 0.2611
# 21/51, train_loss: 0.8321
# 22/51, train_loss: 0.9705
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 0.9860
# 25/51, train_loss: 0.2651
# 26/51, train_loss: 0.4616
# 27/51, train_loss: 0.7371
# 28/51, train_loss: 0.3677
# 29/51, train_loss: 0.3149
# 30/51, train_loss: 0.3223
# 31/51, train_loss: 0.5836
# 32/51, train_loss: 0.2328
# 33/51, train_loss: 0.4376
# 34/51, train_loss: 0.3546
# 35/51, train_loss: 0.6749
# 36/51, train_loss: 0.2865
# 37/51, train_loss: 0.6088
# 38/51, train_loss: 0.5973
# 39/51, train_loss: 0.5496
# 40/51, train_loss: 0.3839
# 41/51, train_loss: 0.1922
# 42/51, train_loss: 0.4822
# 43/51, train_loss: 0.3222
# 44/51, train_loss: 1.0000
# 45/51, train_loss: 0.2814
# 46/51, train_loss: 0.9999
# 47/51, train_loss: 0.4059
# 48/51, train_loss: 0.3278
# 49/51, train_loss: 0.4624
# 50/51, train_loss: 0.2720
# 51/51, train_loss: 0.9996
# epoch 36 average loss: 0.5517
# current epoch: 36, current mean dice: 0.0002, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 37/100
# 1/51, train_loss: 1.0000
# 2/51, train_loss: 0.8515
# 3/51, train_loss: 0.6646
# 4/51, train_loss: 0.1791
# 5/51, train_loss: 0.3273
# 6/51, train_loss: 0.2758
# 7/51, train_loss: 0.4334
# 8/51, train_loss: 0.9999
# 9/51, train_loss: 0.6185
# 10/51, train_loss: 0.7687
# 11/51, train_loss: 0.5838
# 12/51, train_loss: 1.0000
# 13/51, train_loss: 0.5007
# 14/51, train_loss: 0.4367
# 15/51, train_loss: 0.3254
# 16/51, train_loss: 0.2249
# 17/51, train_loss: 0.5635
# 18/51, train_loss: 0.4775
# 19/51, train_loss: 0.3707
# 20/51, train_loss: 1.0000
# 21/51, train_loss: 0.3040
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.9997
# 24/51, train_loss: 0.9899
# 25/51, train_loss: 0.3427
# 26/51, train_loss: 0.9888
# 27/51, train_loss: 0.8923
# 28/51, train_loss: 0.3839
# 29/51, train_loss: 0.3128
# 30/51, train_loss: 0.2155
# 31/51, train_loss: 0.4674
# 32/51, train_loss: 0.2497
# 33/51, train_loss: 0.2216
# 34/51, train_loss: 0.3775
# 35/51, train_loss: 0.8712
# 36/51, train_loss: 0.5829
# 37/51, train_loss: 0.2238
# 38/51, train_loss: 0.3986
# 39/51, train_loss: 0.4991
# 40/51, train_loss: 0.3573
# 41/51, train_loss: 0.1994
# 42/51, train_loss: 0.7325
# 43/51, train_loss: 1.0000
# 44/51, train_loss: 0.7042
# 45/51, train_loss: 0.3857
# 46/51, train_loss: 0.6449
# 47/51, train_loss: 0.3660
# 48/51, train_loss: 0.3565
# 49/51, train_loss: 0.5404
# 50/51, train_loss: 0.9749
# 51/51, train_loss: 1.0000
# epoch 37 average loss: 0.5723
# current epoch: 37, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 38/100
# 1/51, train_loss: 0.4202
# 2/51, train_loss: 0.4187
# 3/51, train_loss: 0.3373
# 4/51, train_loss: 0.3318
# 5/51, train_loss: 0.2766
# 6/51, train_loss: 0.3540
# 7/51, train_loss: 0.2302
# 8/51, train_loss: 0.9996
# 9/51, train_loss: 0.8477
# 10/51, train_loss: 0.3493
# 11/51, train_loss: 0.8467
# 12/51, train_loss: 0.5448
# 13/51, train_loss: 0.2201
# 14/51, train_loss: 0.9858
# 15/51, train_loss: 1.0000
# 16/51, train_loss: 0.7261
# 17/51, train_loss: 0.6487
# 18/51, train_loss: 0.3725
# 19/51, train_loss: 0.2461
# 20/51, train_loss: 0.5849
# 21/51, train_loss: 0.9991
# 22/51, train_loss: 0.7501
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 0.3530
# 25/51, train_loss: 0.4281
# 26/51, train_loss: 0.4592
# 27/51, train_loss: 0.9212
# 28/51, train_loss: 0.9957
# 29/51, train_loss: 0.2267
# 30/51, train_loss: 0.5729
# 31/51, train_loss: 1.0000
# 32/51, train_loss: 0.2942
# 33/51, train_loss: 0.8691
# 34/51, train_loss: 0.4814
# 35/51, train_loss: 0.3192
# 36/51, train_loss: 1.0000
# 37/51, train_loss: 0.3104
# 38/51, train_loss: 0.5965
# 39/51, train_loss: 0.3770
# 40/51, train_loss: 0.3166
# 41/51, train_loss: 0.2894
# 42/51, train_loss: 0.6172
# 43/51, train_loss: 0.9990
# 44/51, train_loss: 0.4469
# 45/51, train_loss: 1.0000
# 46/51, train_loss: 0.3140
# 47/51, train_loss: 0.3749
# 48/51, train_loss: 0.2070
# 49/51, train_loss: 0.3595
# 50/51, train_loss: 0.4331
# 51/51, train_loss: 0.3631
# epoch 38 average loss: 0.5572
# current epoch: 38, current mean dice: 0.0000, best mean dice: 0.0029, at epoch: 9
# ------------
# Epoch 39/100
# 1/51, train_loss: 0.6087
# 2/51, train_loss: 0.3244
# 3/51, train_loss: 0.2473
# 4/51, train_loss: 0.3087
# 5/51, train_loss: 0.4337
# 6/51, train_loss: 0.5376
# 7/51, train_loss: 0.3096
# 8/51, train_loss: 0.4323
# 9/51, train_loss: 0.9918
# 10/51, train_loss: 0.4385
# 11/51, train_loss: 0.9327
# 12/51, train_loss: 0.4658
# 13/51, train_loss: 0.6871
# 14/51, train_loss: 1.0000
# 15/51, train_loss: 0.3989
# 16/51, train_loss: 0.4315
# 17/51, train_loss: 0.3774
# 18/51, train_loss: 0.4470
# 19/51, train_loss: 0.3628
# 20/51, train_loss: 0.9937
# 21/51, train_loss: 0.3586
# 22/51, train_loss: 0.9890
# 23/51, train_loss: 0.5822
# 24/51, train_loss: 0.4338
# 25/51, train_loss: 0.3340
# 26/51, train_loss: 0.4536
# 27/51, train_loss: 0.5782
# 28/51, train_loss: 0.5797
# 29/51, train_loss: 0.2665
# 30/51, train_loss: 0.2193
# 31/51, train_loss: 0.6436
# 32/51, train_loss: 0.9993
# 33/51, train_loss: 0.2218
# 34/51, train_loss: 0.8216
# 35/51, train_loss: 0.6113
# 36/51, train_loss: 0.7493
# 37/51, train_loss: 0.2645
# 38/51, train_loss: 1.0000
# 39/51, train_loss: 0.2305
# 40/51, train_loss: 0.2269
# 41/51, train_loss: 0.6729
# 42/51, train_loss: 1.0000
# 43/51, train_loss: 1.0000
# 44/51, train_loss: 0.3371
# 45/51, train_loss: 0.3120
# 46/51, train_loss: 0.8804
# 47/51, train_loss: 1.0000
# 48/51, train_loss: 0.5889
# 49/51, train_loss: 0.6094
# 50/51, train_loss: 0.4539
# 51/51, train_loss: 0.4349
# epoch 39 average loss: 0.5605
# saved new best metric model!!!
# current epoch: 39, current mean dice: 0.0052, best mean dice: 0.0052, at epoch: 39
# ------------
# Epoch 40/100
# 1/51, train_loss: 0.3292
# 2/51, train_loss: 0.1676
# 3/51, train_loss: 0.4724
# 4/51, train_loss: 0.1052
# 5/51, train_loss: 0.2971
# 6/51, train_loss: 0.3387
# 7/51, train_loss: 1.0000
# 8/51, train_loss: 0.6571
# 9/51, train_loss: 0.8156
# 10/51, train_loss: 0.6316
# 11/51, train_loss: 1.0000
# 12/51, train_loss: 0.3301
# 13/51, train_loss: 0.4742
# 14/51, train_loss: 0.3400
# 15/51, train_loss: 0.9292
# 16/51, train_loss: 0.3952
# 17/51, train_loss: 0.5614
# 18/51, train_loss: 1.0000
# 19/51, train_loss: 0.4804
# 20/51, train_loss: 0.3767
# 21/51, train_loss: 0.9242
# 22/51, train_loss: 0.5313
# 23/51, train_loss: 0.5097
# 24/51, train_loss: 0.5400
# 25/51, train_loss: 0.3766
# 26/51, train_loss: 0.2977
# 27/51, train_loss: 0.3499
# 28/51, train_loss: 0.3974
# 29/51, train_loss: 0.4558
# 30/51, train_loss: 0.9993
# 31/51, train_loss: 0.3346
# 32/51, train_loss: 0.9998
# 33/51, train_loss: 1.0000
# 34/51, train_loss: 0.6188
# 35/51, train_loss: 0.5324
# 36/51, train_loss: 0.4867
# 37/51, train_loss: 0.2420
# 38/51, train_loss: 0.3622
# 39/51, train_loss: 0.8012
# 40/51, train_loss: 0.1948
# 41/51, train_loss: 0.8163
# 42/51, train_loss: 0.2604
# 43/51, train_loss: 0.1836
# 44/51, train_loss: 0.4316
# 45/51, train_loss: 0.3214
# 46/51, train_loss: 0.2979
# 47/51, train_loss: 0.3051
# 48/51, train_loss: 1.0000
# 49/51, train_loss: 0.4179
# 50/51, train_loss: 0.2053
# 51/51, train_loss: 0.3311
# epoch 40 average loss: 0.5142
# current epoch: 40, current mean dice: 0.0012, best mean dice: 0.0052, at epoch: 39
# ------------
# Epoch 41/100
# 1/51, train_loss: 0.7242
# 2/51, train_loss: 0.4231
# 3/51, train_loss: 0.7510
# 4/51, train_loss: 0.3582
# 5/51, train_loss: 1.0000
# 6/51, train_loss: 0.3997
# 7/51, train_loss: 0.1932
# 8/51, train_loss: 0.6232
# 9/51, train_loss: 0.4111
# 10/51, train_loss: 1.0000
# 11/51, train_loss: 0.3965
# 12/51, train_loss: 0.4475
# 13/51, train_loss: 0.9994
# 14/51, train_loss: 0.3837
# 15/51, train_loss: 0.2698
# 16/51, train_loss: 0.6337
# 17/51, train_loss: 0.6124
# 18/51, train_loss: 0.2398
# 19/51, train_loss: 0.2156
# 20/51, train_loss: 0.3506
# 21/51, train_loss: 0.2052
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 0.5180
# 25/51, train_loss: 0.3836
# 26/51, train_loss: 0.3710
# 27/51, train_loss: 0.7492
# 28/51, train_loss: 0.6095
# 29/51, train_loss: 0.4637
# 30/51, train_loss: 0.3691
# 31/51, train_loss: 0.3278
# 32/51, train_loss: 0.2145
# 33/51, train_loss: 0.1951
# 34/51, train_loss: 0.3352
# 35/51, train_loss: 0.9996
# 36/51, train_loss: 0.4826
# 37/51, train_loss: 0.6885
# 38/51, train_loss: 1.0000
# 39/51, train_loss: 1.0000
# 40/51, train_loss: 0.2869
# 41/51, train_loss: 0.2433
# 42/51, train_loss: 0.3650
# 43/51, train_loss: 0.7401
# 44/51, train_loss: 0.3759
# 45/51, train_loss: 0.6057
# 46/51, train_loss: 0.9937
# 47/51, train_loss: 0.1806
# 48/51, train_loss: 0.5569
# 49/51, train_loss: 0.9404
# 50/51, train_loss: 0.6626
# 51/51, train_loss: 0.3524
# epoch 41 average loss: 0.5421
# current epoch: 41, current mean dice: 0.0000, best mean dice: 0.0052, at epoch: 39
# ------------
# Epoch 42/100
# 1/51, train_loss: 0.2662
# 2/51, train_loss: 0.3150
# 3/51, train_loss: 0.1938
# 4/51, train_loss: 0.1594
# 5/51, train_loss: 0.4391
# 6/51, train_loss: 0.7631
# 7/51, train_loss: 0.4404
# 8/51, train_loss: 0.9995
# 9/51, train_loss: 0.6671
# 10/51, train_loss: 0.4231
# 11/51, train_loss: 0.2120
# 12/51, train_loss: 0.9269
# 13/51, train_loss: 0.3941
# 14/51, train_loss: 0.2418
# 15/51, train_loss: 0.3681
# 16/51, train_loss: 0.7588
# 17/51, train_loss: 1.0000
# 18/51, train_loss: 0.3335
# 19/51, train_loss: 0.3656
# 20/51, train_loss: 1.0000
# 21/51, train_loss: 0.6158
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.6664
# 24/51, train_loss: 0.3627
# 25/51, train_loss: 0.3870
# 26/51, train_loss: 0.4169
# 27/51, train_loss: 0.3882
# 28/51, train_loss: 0.5382
# 29/51, train_loss: 0.2876
# 30/51, train_loss: 0.3778
# 31/51, train_loss: 0.5982
# 32/51, train_loss: 0.5824
# 33/51, train_loss: 0.7293
# 34/51, train_loss: 0.7695
# 35/51, train_loss: 0.5241
# 36/51, train_loss: 1.0000
# 37/51, train_loss: 0.2570
# 38/51, train_loss: 0.3588
# 39/51, train_loss: 1.0000
# 40/51, train_loss: 0.2282
# 41/51, train_loss: 0.3178
# 42/51, train_loss: 0.9809
# 43/51, train_loss: 0.2781
# 44/51, train_loss: 0.1873
# 45/51, train_loss: 0.3613
# 46/51, train_loss: 0.7161
# 47/51, train_loss: 0.3785
# 48/51, train_loss: 0.5325
# 49/51, train_loss: 0.7341
# 50/51, train_loss: 0.3522
# 51/51, train_loss: 1.0000
# epoch 42 average loss: 0.5332
# current epoch: 42, current mean dice: 0.0000, best mean dice: 0.0052, at epoch: 39
# ------------
# Epoch 43/100
# 1/51, train_loss: 0.2669
# 2/51, train_loss: 0.2951
# 3/51, train_loss: 0.2561
# ...
# 3/51, train_loss: 0.2433
# 4/51, train_loss: 0.1477
# 5/51, train_loss: 0.3863
# 6/51, train_loss: 0.3091
# 7/51, train_loss: 0.2990
# 8/51, train_loss: 0.3790
# 9/51, train_loss: 0.5508
# 10/51, train_loss: 0.2493
# 11/51, train_loss: 0.5739
# 12/51, train_loss: 0.9396
# 13/51, train_loss: 0.2670
# 14/51, train_loss: 0.3795
# 15/51, train_loss: 0.7589
# 16/51, train_loss: 0.3950
# 17/51, train_loss: 1.0000
# 18/51, train_loss: 0.5311
# 19/51, train_loss: 0.2289
# 20/51, train_loss: 0.3446
# 21/51, train_loss: 0.2232
# 22/51, train_loss: 0.2585
# 23/51, train_loss: 0.3455
# 24/51, train_loss: 0.4437
# 25/51, train_loss: 0.5057
# 26/51, train_loss: 0.2756
# 27/51, train_loss: 0.3290
# 28/51, train_loss: 0.4252
# 29/51, train_loss: 0.1472
# 30/51, train_loss: 0.4404
# 31/51, train_loss: 0.1603
# 32/51, train_loss: 1.0000
# 33/51, train_loss: 0.1953
# 34/51, train_loss: 0.2041
# 35/51, train_loss: 0.7076
# 36/51, train_loss: 0.5859
# 37/51, train_loss: 0.2589
# 38/51, train_loss: 0.1741
# 39/51, train_loss: 0.3039
# 40/51, train_loss: 0.9989
# 41/51, train_loss: 1.0000
# 42/51, train_loss: 0.9663
# 43/51, train_loss: 0.1682
# 44/51, train_loss: 0.5046
# 45/51, train_loss: 0.1968
# 46/51, train_loss: 0.1571
# 47/51, train_loss: 0.2562
# 48/51, train_loss: 0.2175
# 49/51, train_loss: 0.1400
# 50/51, train_loss: 0.1594
# 51/51, train_loss: 0.4831
# epoch 90 average loss: 0.4072
# current epoch: 90, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 91/100
# 1/51, train_loss: 0.2088
# 2/51, train_loss: 0.3854
# 3/51, train_loss: 0.1991
# 4/51, train_loss: 0.1061
# 5/51, train_loss: 0.2957
# 6/51, train_loss: 0.4402
# 7/51, train_loss: 0.2140
# 8/51, train_loss: 0.1297
# 9/51, train_loss: 1.0000
# 10/51, train_loss: 0.3469
# 11/51, train_loss: 0.2103
# 12/51, train_loss: 0.2984
# 13/51, train_loss: 0.3227
# 14/51, train_loss: 0.3287
# 15/51, train_loss: 0.2510
# 16/51, train_loss: 0.4801
# 17/51, train_loss: 0.2660
# 18/51, train_loss: 0.3915
# 19/51, train_loss: 0.2795
# 20/51, train_loss: 0.4667
# 21/51, train_loss: 0.3011
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.4756
# 24/51, train_loss: 0.5255
# 25/51, train_loss: 0.3601
# 26/51, train_loss: 1.0000
# 27/51, train_loss: 0.1997
# 28/51, train_loss: 0.3148
# 29/51, train_loss: 0.2590
# 30/51, train_loss: 0.1014
# 31/51, train_loss: 0.1353
# 32/51, train_loss: 0.2270
# 33/51, train_loss: 1.0000
# 34/51, train_loss: 0.3892
# 35/51, train_loss: 0.3930
# 36/51, train_loss: 1.0000
# 37/51, train_loss: 0.1355
# 38/51, train_loss: 0.2401
# 39/51, train_loss: 0.1603
# 40/51, train_loss: 0.1520
# 41/51, train_loss: 0.2632
# 42/51, train_loss: 0.2398
# 43/51, train_loss: 0.4354
# 44/51, train_loss: 0.2556
# 45/51, train_loss: 0.1457
# 46/51, train_loss: 0.1684
# 47/51, train_loss: 0.2530
# 48/51, train_loss: 0.4826
# 49/51, train_loss: 0.3821
# 50/51, train_loss: 0.2164
# 51/51, train_loss: 0.1863
# epoch 91 average loss: 0.3533
# current epoch: 91, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 92/100
# 1/51, train_loss: 0.1538
# 2/51, train_loss: 0.3245
# 3/51, train_loss: 0.2647
# 4/51, train_loss: 0.2373
# 5/51, train_loss: 0.5217
# 6/51, train_loss: 0.3307
# 7/51, train_loss: 0.3039
# 8/51, train_loss: 0.3152
# 9/51, train_loss: 0.3053
# 10/51, train_loss: 0.5331
# 11/51, train_loss: 0.3139
# 12/51, train_loss: 0.3771
# 13/51, train_loss: 0.4285
# 14/51, train_loss: 0.2160
# 15/51, train_loss: 1.0000
# 16/51, train_loss: 0.3964
# 17/51, train_loss: 0.3116
# 18/51, train_loss: 0.2022
# 19/51, train_loss: 0.3645
# 20/51, train_loss: 0.2852
# 21/51, train_loss: 0.2585
# 22/51, train_loss: 0.3514
# 23/51, train_loss: 0.4224
# 24/51, train_loss: 0.3102
# 25/51, train_loss: 0.2186
# 26/51, train_loss: 0.3373
# 27/51, train_loss: 0.2169
# 28/51, train_loss: 0.2685
# 29/51, train_loss: 0.1107
# 30/51, train_loss: 0.2477
# 31/51, train_loss: 0.3860
# 32/51, train_loss: 0.1665
# 33/51, train_loss: 0.1425
# 34/51, train_loss: 0.4949
# 35/51, train_loss: 0.4739
# 36/51, train_loss: 0.4112
# 37/51, train_loss: 0.2275
# 38/51, train_loss: 0.2460
# 39/51, train_loss: 0.1581
# 40/51, train_loss: 0.2407
# 41/51, train_loss: 0.4569
# 42/51, train_loss: 0.1698
# 43/51, train_loss: 0.1790
# 44/51, train_loss: 0.1301
# 45/51, train_loss: 0.2257
# 46/51, train_loss: 1.0000
# 47/51, train_loss: 1.0000
# 48/51, train_loss: 0.2773
# 49/51, train_loss: 1.0000
# 50/51, train_loss: 0.3169
# 51/51, train_loss: 0.2980
# epoch 92 average loss: 0.3515
# current epoch: 92, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 93/100
# 1/51, train_loss: 0.2444
# 2/51, train_loss: 0.3622
# 3/51, train_loss: 0.4116
# 4/51, train_loss: 0.2191
# 5/51, train_loss: 0.2959
# 6/51, train_loss: 0.8760
# 7/51, train_loss: 0.4740
# 8/51, train_loss: 0.3513
# 9/51, train_loss: 0.3349
# 10/51, train_loss: 0.2880
# 11/51, train_loss: 0.2831
# 12/51, train_loss: 0.5385
# 13/51, train_loss: 0.3162
# 14/51, train_loss: 0.1727
# 15/51, train_loss: 0.3042
# 16/51, train_loss: 0.2830
# 17/51, train_loss: 0.3068
# 18/51, train_loss: 0.2536
# 19/51, train_loss: 0.4008
# 20/51, train_loss: 0.5968
# 21/51, train_loss: 0.3787
# 22/51, train_loss: 1.0000
# 23/51, train_loss: 0.9996
# 24/51, train_loss: 0.2692
# 25/51, train_loss: 0.3209
# 26/51, train_loss: 0.1669
# 27/51, train_loss: 0.2372
# 28/51, train_loss: 0.2419
# 29/51, train_loss: 0.1438
# 30/51, train_loss: 0.1276
# 31/51, train_loss: 0.2464
# 32/51, train_loss: 0.2319
# 33/51, train_loss: 0.5254
# 34/51, train_loss: 0.1910
# 35/51, train_loss: 0.5286
# 36/51, train_loss: 0.4634
# 37/51, train_loss: 0.1878
# 38/51, train_loss: 0.2504
# 39/51, train_loss: 0.1447
# 40/51, train_loss: 0.1171
# 41/51, train_loss: 0.1745
# 42/51, train_loss: 0.1656
# 43/51, train_loss: 1.0000
# 44/51, train_loss: 0.2320
# 45/51, train_loss: 0.3803
# 46/51, train_loss: 0.2445
# 47/51, train_loss: 0.4925
# 48/51, train_loss: 0.1821
# 49/51, train_loss: 0.2767
# 50/51, train_loss: 1.0000
# 51/51, train_loss: 1.0000
# epoch 93 average loss: 0.3771
# current epoch: 93, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 94/100
# 1/51, train_loss: 0.3085
# 2/51, train_loss: 0.1772
# 3/51, train_loss: 0.1935
# 4/51, train_loss: 0.1661
# 5/51, train_loss: 0.3418
# 6/51, train_loss: 0.2149
# 7/51, train_loss: 0.3405
# 8/51, train_loss: 0.3156
# 9/51, train_loss: 0.4709
# 10/51, train_loss: 0.4631
# 11/51, train_loss: 0.3179
# 12/51, train_loss: 0.8869
# 13/51, train_loss: 0.2211
# 14/51, train_loss: 0.2733
# 15/51, train_loss: 0.1675
# 16/51, train_loss: 0.3114
# 17/51, train_loss: 0.1883
# 18/51, train_loss: 0.2691
# 19/51, train_loss: 1.0000
# 20/51, train_loss: 0.2453
# 21/51, train_loss: 0.3032
# 22/51, train_loss: 0.3452
# 23/51, train_loss: 0.2142
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.3413
# 26/51, train_loss: 0.2456
# 27/51, train_loss: 0.4370
# 28/51, train_loss: 0.1943
# 29/51, train_loss: 0.1393
# 30/51, train_loss: 0.2765
# 31/51, train_loss: 0.1381
# 32/51, train_loss: 1.0000
# 33/51, train_loss: 0.5872
# 34/51, train_loss: 0.1492
# 35/51, train_loss: 0.2985
# 36/51, train_loss: 0.6328
# 37/51, train_loss: 0.2385
# 38/51, train_loss: 0.1856
# 39/51, train_loss: 0.1947
# 40/51, train_loss: 1.0000
# 41/51, train_loss: 0.1210
# 42/51, train_loss: 0.1748
# 43/51, train_loss: 0.2611
# 44/51, train_loss: 0.3163
# 45/51, train_loss: 0.3583
# 46/51, train_loss: 0.6917
# 47/51, train_loss: 0.4250
# 48/51, train_loss: 0.2222
# 49/51, train_loss: 0.2405
# 50/51, train_loss: 0.3469
# 51/51, train_loss: 0.3287
# epoch 94 average loss: 0.3584
# current epoch: 94, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 95/100
# 1/51, train_loss: 0.1634
# 2/51, train_loss: 0.2008
# 3/51, train_loss: 0.2772
# 4/51, train_loss: 0.2208
# 5/51, train_loss: 0.3315
# 6/51, train_loss: 0.3442
# 7/51, train_loss: 1.0000
# 8/51, train_loss: 0.2772
# 9/51, train_loss: 0.4382
# 10/51, train_loss: 0.3484
# 11/51, train_loss: 1.0000
# 12/51, train_loss: 0.3815
# 13/51, train_loss: 0.3021
# 14/51, train_loss: 0.2658
# 15/51, train_loss: 0.3064
# 16/51, train_loss: 0.1872
# 17/51, train_loss: 0.3077
# 18/51, train_loss: 0.2518
# 19/51, train_loss: 0.2413
# 20/51, train_loss: 1.0000
# 21/51, train_loss: 0.2769
# 22/51, train_loss: 0.3351
# 23/51, train_loss: 1.0000
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 0.3997
# 26/51, train_loss: 0.2424
# 27/51, train_loss: 0.1929
# 28/51, train_loss: 0.3345
# 29/51, train_loss: 0.1806
# 30/51, train_loss: 0.1168
# 31/51, train_loss: 0.3231
# 32/51, train_loss: 0.2612
# 33/51, train_loss: 0.1709
# 34/51, train_loss: 0.1674
# 35/51, train_loss: 0.6157
# 36/51, train_loss: 0.4423
# 37/51, train_loss: 0.3152
# 38/51, train_loss: 0.3067
# 39/51, train_loss: 0.1544
# 40/51, train_loss: 0.2003
# 41/51, train_loss: 0.2733
# 42/51, train_loss: 0.4302
# 43/51, train_loss: 0.3604
# 44/51, train_loss: 0.2809
# 45/51, train_loss: 0.1714
# 46/51, train_loss: 0.4526
# 47/51, train_loss: 0.1876
# 48/51, train_loss: 0.1917
# 49/51, train_loss: 0.3627
# 50/51, train_loss: 0.3221
# 51/51, train_loss: 0.5753
# epoch 95 average loss: 0.3625
# current epoch: 95, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 96/100
# 1/51, train_loss: 0.1579
# 2/51, train_loss: 0.2319
# 3/51, train_loss: 1.0000
# 4/51, train_loss: 0.1063
# 5/51, train_loss: 0.1812
# 6/51, train_loss: 0.2324
# 7/51, train_loss: 0.4970
# 8/51, train_loss: 0.4287
# 9/51, train_loss: 0.4596
# 10/51, train_loss: 0.2642
# 11/51, train_loss: 0.2341
# 12/51, train_loss: 0.2856
# 13/51, train_loss: 0.5562
# 14/51, train_loss: 0.3877
# 15/51, train_loss: 0.4127
# 16/51, train_loss: 0.9985
# 17/51, train_loss: 0.3794
# 18/51, train_loss: 0.2934
# 19/51, train_loss: 0.3808
# 20/51, train_loss: 1.0000
# 21/51, train_loss: 0.1935
# 22/51, train_loss: 0.5221
# 23/51, train_loss: 0.3718
# 24/51, train_loss: 0.2970
# 25/51, train_loss: 0.3823
# 26/51, train_loss: 0.3362
# 27/51, train_loss: 0.1920
# 28/51, train_loss: 0.6665
# 29/51, train_loss: 0.2222
# 30/51, train_loss: 0.2972
# 31/51, train_loss: 0.1650
# 32/51, train_loss: 0.1827
# 33/51, train_loss: 1.0000
# 34/51, train_loss: 0.3932
# 35/51, train_loss: 0.3837
# 36/51, train_loss: 0.2154
# 37/51, train_loss: 0.2105
# 38/51, train_loss: 0.2371
# 39/51, train_loss: 0.4813
# 40/51, train_loss: 0.1408
# 41/51, train_loss: 0.2542
# 42/51, train_loss: 0.2840
# 43/51, train_loss: 0.4725
# 44/51, train_loss: 0.2473
# 45/51, train_loss: 0.3397
# 46/51, train_loss: 0.1683
# 47/51, train_loss: 0.4379
# 48/51, train_loss: 0.1755
# 49/51, train_loss: 0.4400
# 50/51, train_loss: 0.4733
# 51/51, train_loss: 0.1745
# epoch 96 average loss: 0.3695
# current epoch: 96, current mean dice: 0.0101, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 97/100
# 1/51, train_loss: 0.6032
# 2/51, train_loss: 0.3180
# 3/51, train_loss: 0.2239
# 4/51, train_loss: 0.3264
# 5/51, train_loss: 0.1959
# 6/51, train_loss: 0.3251
# 7/51, train_loss: 0.2812
# 8/51, train_loss: 1.0000
# 9/51, train_loss: 0.5667
# 10/51, train_loss: 0.1691
# 11/51, train_loss: 0.3061
# 12/51, train_loss: 0.5165
# 13/51, train_loss: 0.3066
# 14/51, train_loss: 0.4030
# 15/51, train_loss: 0.4038
# 16/51, train_loss: 0.2347
# 17/51, train_loss: 0.3054
# 18/51, train_loss: 0.5509
# 19/51, train_loss: 0.3959
# 20/51, train_loss: 0.3100
# 21/51, train_loss: 0.9333
# 22/51, train_loss: 0.3027
# 23/51, train_loss: 0.3981
# 24/51, train_loss: 0.2610
# 25/51, train_loss: 0.3721
# 26/51, train_loss: 0.2413
# 27/51, train_loss: 0.3139
# 28/51, train_loss: 0.4746
# 29/51, train_loss: 0.3083
# 30/51, train_loss: 0.1793
# 31/51, train_loss: 0.2462
# 32/51, train_loss: 0.2408
# 33/51, train_loss: 0.3848
# 34/51, train_loss: 0.2562
# 35/51, train_loss: 0.4176
# 36/51, train_loss: 0.4105
# 37/51, train_loss: 0.3090
# 38/51, train_loss: 0.3869
# 39/51, train_loss: 1.0000
# 40/51, train_loss: 0.2097
# 41/51, train_loss: 0.2588
# 42/51, train_loss: 0.4003
# 43/51, train_loss: 0.9061
# 44/51, train_loss: 0.2633
# 45/51, train_loss: 0.1672
# 46/51, train_loss: 0.2726
# 47/51, train_loss: 0.1304
# 48/51, train_loss: 0.4026
# 49/51, train_loss: 0.2846
# 50/51, train_loss: 1.0000
# 51/51, train_loss: 0.2453
# epoch 97 average loss: 0.3867
# current epoch: 97, current mean dice: 0.0010, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 98/100
# 1/51, train_loss: 0.1506
# 2/51, train_loss: 0.4389
# 3/51, train_loss: 0.4345
# 4/51, train_loss: 0.3771
# 5/51, train_loss: 0.3161
# 6/51, train_loss: 0.2805
# 7/51, train_loss: 0.3557
# 8/51, train_loss: 0.2993
# 9/51, train_loss: 0.3726
# 10/51, train_loss: 1.0000
# 11/51, train_loss: 0.4283
# 12/51, train_loss: 0.4777
# 13/51, train_loss: 0.3318
# 14/51, train_loss: 0.2645
# 15/51, train_loss: 0.3761
# 16/51, train_loss: 0.2694
# 17/51, train_loss: 0.2839
# 18/51, train_loss: 0.3522
# 19/51, train_loss: 0.3812
# 20/51, train_loss: 0.1716
# 21/51, train_loss: 0.4681
# 22/51, train_loss: 0.2843
# 23/51, train_loss: 0.4229
# 24/51, train_loss: 0.9998
# 25/51, train_loss: 0.2224
# 26/51, train_loss: 0.2404
# 27/51, train_loss: 1.0000
# 28/51, train_loss: 0.3103
# 29/51, train_loss: 0.2116
# 30/51, train_loss: 0.1845
# 31/51, train_loss: 0.1788
# 32/51, train_loss: 0.2591
# 33/51, train_loss: 0.3923
# 34/51, train_loss: 0.1458
# 35/51, train_loss: 0.1764
# 36/51, train_loss: 0.2593
# 37/51, train_loss: 0.2516
# 38/51, train_loss: 0.1896
# 39/51, train_loss: 0.2700
# 40/51, train_loss: 0.5721
# 41/51, train_loss: 0.2689
# 42/51, train_loss: 0.1945
# 43/51, train_loss: 0.2245
# 44/51, train_loss: 0.2066
# 45/51, train_loss: 0.4305
# 46/51, train_loss: 0.4983
# 47/51, train_loss: 0.3329
# 48/51, train_loss: 0.1780
# 49/51, train_loss: 1.0000
# 50/51, train_loss: 0.4136
# 51/51, train_loss: 0.4987
# epoch 98 average loss: 0.3656
# current epoch: 98, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 99/100
# 1/51, train_loss: 0.1740
# 2/51, train_loss: 0.1560
# 3/51, train_loss: 0.8477
# 4/51, train_loss: 0.1703
# 5/51, train_loss: 0.1777
# 6/51, train_loss: 0.3835
# 7/51, train_loss: 0.2924
# 8/51, train_loss: 0.2914
# 9/51, train_loss: 0.6961
# 10/51, train_loss: 0.3214
# 11/51, train_loss: 0.2484
# 12/51, train_loss: 0.2728
# 13/51, train_loss: 0.2797
# 14/51, train_loss: 0.3332
# 15/51, train_loss: 0.3061
# 16/51, train_loss: 0.3073
# 17/51, train_loss: 0.3310
# 18/51, train_loss: 0.5954
# 19/51, train_loss: 0.2732
# 20/51, train_loss: 0.3039
# 21/51, train_loss: 1.0000
# 22/51, train_loss: 0.1526
# 23/51, train_loss: 0.5459
# 24/51, train_loss: 0.2062
# 25/51, train_loss: 0.5067
# 26/51, train_loss: 1.0000
# 27/51, train_loss: 0.2435
# 28/51, train_loss: 0.3856
# 29/51, train_loss: 0.1028
# 30/51, train_loss: 0.1424
# 31/51, train_loss: 0.3837
# 32/51, train_loss: 0.5026
# 33/51, train_loss: 0.1446
# 34/51, train_loss: 0.3365
# 35/51, train_loss: 0.3952
# 36/51, train_loss: 0.3099
# 37/51, train_loss: 0.3597
# 38/51, train_loss: 0.3058
# 39/51, train_loss: 0.2096
# 40/51, train_loss: 0.2781
# 41/51, train_loss: 0.2001
# 42/51, train_loss: 0.2566
# 43/51, train_loss: 0.1606
# 44/51, train_loss: 1.0000
# 45/51, train_loss: 0.1883
# 46/51, train_loss: 0.2099
# 47/51, train_loss: 0.4075
# 48/51, train_loss: 1.0000
# 49/51, train_loss: 0.2281
# 50/51, train_loss: 0.1647
# 51/51, train_loss: 0.6292
# epoch 99 average loss: 0.3670
# current epoch: 99, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# ------------
# Epoch 100/100
# 1/51, train_loss: 0.2650
# 2/51, train_loss: 0.1456
# 3/51, train_loss: 0.1095
# 4/51, train_loss: 0.1973
# 5/51, train_loss: 0.2630
# 6/51, train_loss: 0.2890
# 7/51, train_loss: 0.2639
# 8/51, train_loss: 0.4199
# 9/51, train_loss: 0.3330
# 10/51, train_loss: 0.2968
# 11/51, train_loss: 0.3623
# 12/51, train_loss: 0.2835
# 13/51, train_loss: 0.2986
# 14/51, train_loss: 0.6397
# 15/51, train_loss: 0.2387
# 16/51, train_loss: 0.2295
# 17/51, train_loss: 0.3499
# 18/51, train_loss: 0.2664
# 19/51, train_loss: 0.4262
# 20/51, train_loss: 0.1974
# 21/51, train_loss: 0.2866
# 22/51, train_loss: 0.2259
# 23/51, train_loss: 0.3020
# 24/51, train_loss: 1.0000
# 25/51, train_loss: 1.0000
# 26/51, train_loss: 0.2937
# 27/51, train_loss: 0.2502
# 28/51, train_loss: 0.3342
# 29/51, train_loss: 0.1752
# 30/51, train_loss: 1.0000
# 31/51, train_loss: 0.2059
# 32/51, train_loss: 0.1601
# 33/51, train_loss: 0.2205
# 34/51, train_loss: 0.5402
# 35/51, train_loss: 0.6901
# 36/51, train_loss: 1.0000
# 37/51, train_loss: 0.1299
# 38/51, train_loss: 0.4190
# 39/51, train_loss: 0.1448
# 40/51, train_loss: 0.3639
# 41/51, train_loss: 0.3741
# 42/51, train_loss: 0.4931
# 43/51, train_loss: 0.1877
# 44/51, train_loss: 0.2193
# 45/51, train_loss: 0.1923
# 46/51, train_loss: 0.3708
# 47/51, train_loss: 0.4363
# 48/51, train_loss: 0.1563
# 49/51, train_loss: 0.2041
# 50/51, train_loss: 0.4637
# 51/51, train_loss: 0.4053
# epoch 100 average loss: 0.3553
# current epoch: 100, current mean dice: 0.0000, best mean dice: 0.0243, at epoch: 83
# train completed, best metric: 0.0243 at epoch: 83

# %%
## Define your path below, it will be saed somewhere in your google drive

rootname = '/content/drive/MyDrive'
# PATH_NAME = rootname + *enter your path here*
PATH_NAME = rootname + '/model05lr'

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.savefig('model_1png')
plt.show()
# plt.savefig(PATH_NAME+'model_graph.png')

# %% [markdown]
# # Check model

# %%
checker = first(val_loader)
image, label = checker['image'], checker['label']

# %%
slide = 54
plt.figure("Test Model", (12, 12))

plt.subplot(1, 3, 1)
plt.title("Input")
plt.imshow(image[0, 0, :, :, slide], cmap = "gray")

plt.subplot(1, 3, 2)
plt.title("Label")
plt.imshow(image[0, 0, :, :, slide], cmap = "gray")
plt.imshow(label[0, 0, :, :, slide], cmap = 'jet', alpha = 0.5)

plt.show()

# %%
# plt.figure("Test Model", (12, 12))

# for slide in range(64):
#     plt.subplot(8, 8, slide+1)
#     plt.title("Slide {}".format(slide))
#     plt.imshow(image[0, 0, :, :, slide], cmap="gray")
#     plt.imshow(label[0, 0, :, :, slide], cmap='jet', alpha=0.5)

# plt.tight_layout()
# plt.show()

# %%
model.cpu()
model.load_state_dict(torch.load("best_metric_model.pth"))

with torch.no_grad():
  output = model(image)
  output = torch.nn.Softmax()(output)
  output = torch.round(output)

  print(f"Output shape: {output.shape}")

  slide = 54
  plt.figure("Test Model", (12, 12))

  plt.subplot(1, 3, 1)
  plt.title("Input")
  plt.imshow(image[0, 0, :, :, slide], cmap = "gray")

  plt.subplot(1, 3, 2)
  plt.title("Label")
  plt.imshow(image[0, 0, :, :, slide], cmap = "gray")
  plt.imshow(label[0, 0, :, :, slide], cmap = 'jet', alpha = 0.5)

  plt.subplot(1, 3, 3)
  plt.title("Output")
  plt.imshow(image[0, 0, :, :, slide], cmap = "gray")
  plt.imshow(output[0, 1, :, :, slide], cmap = 'jet', alpha = 0.5)

  plt.show()
# Out:
# Output shape: torch.Size([1, 2, 128, 128, 64])
